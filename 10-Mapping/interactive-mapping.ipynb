# %% [markdown]
# # Mapping
#
# Transportation is about getting from place A to place B.  Therefore, most transportation data has a spatial component to it.  It is nice to be able to put these data on a map and see what is going on.  It is even better if we can put it on a map and interact with the data.  It would be even cooler if we could put our interactive map on a website to show it off!
#
# To do this, we are going to use a package called folium.  You can find the documentation here:
#
# https://folium.readthedocs.io/en/latest/
#
# And access it on github here:
#
# https://github.com/python-visualization/folium

# %% [markdown]
# ### Credits
#
# This lesson draws from the folium quickstart notebook, and from Vik Paruchuri DataQuest lesson:
#
# https://www.dataquest.io/blog/python-data-visualization-libraries/

# %% [markdown]
# ### A side note on static mapping
#
# Sometimes you may want to create a static map instead of an interactive map.  Interactive maps are nice for exploring your data, but static maps work well for an image that you can insert into a paper.  If you want to create static maps, then basemap is a good tool.  Here is a nice lesson focused on mapping earthquake activity:
#
# http://introtopython.org/visualization_earthquakes.html

# %% [markdown]
# ### OK, back to interactive mapping, because that's fun...
#
# It turns out that folium doesn't do much itself.  It is just a wrapper around something called leafletjs.  You can read more about that here:
#
# http://leafletjs.com/index.html
#
# Leaflet is a library in the JavaScript language.  JavaScript is the language used for most web applications.  We could do the same thing using JavaScript and leaflet directly, but then we would have to learn the syntax for another language.  That might not be too hard, but to keep it simple, we'll stick to the python wrapper for now.  It is good to be aware of, though, because if you want more options than folium allows, you can go directly to leaflet.
#
# What makes this possible is the fact that leaflet has a well-defined API.  That means that we can pass data back and forth, even from a different language.

# %% [markdown]
# ### Setup
#
# Start by installing folium using pip.  At a command prompt, type:
#
#     pip install folium
#
# Hmm...when I tried this on my desktop, I get an error that says:
#
#     PermissionError: [WinError 5] Access is denied: 'c:\\program files\\anaconda3\\Lib\\site-packages\\folium'
#
# It seems that it is trying to install something in the program files directory, which Windows has protected.  This will depend on the security settings on your machine.  If you get this error, open a command prompt as an administrator.  In the windows search bar, type cmd.  When you see the command prompt, right click, and select run as administrator.
#
# This did the trick, and now I get:
#
#     Successfully installed folium-0.2.1
#
# In addition, let's go to github and clone the folium repository (https://github.com/python-visualization/folium) to our desktop.  This gives us the source code on our local machine.  What we're really interested in is the examples folder, which gives us a bunch of jupyter notebooks showing how to do different stuff.  You are welcome to explore these as needed.
#
# You also need to install geopandas, which will make it easier to work with goegraphic data.  The pip installer doesn't work (the long explanation is here: http://geoffboeing.com/2014/09/using-geopandas-windows/), so we'll install using anaconda.  Type:
#
#     conda install -c conda-forge geopandas

# %% [markdown]
# Getting Started
# ---------------
#
# To create a base map, simply pass your starting coordinates to Folium:

# %%
import folium

# %%
m = folium.Map(location=[38.034,-84.500])

# %% [markdown]
# to display it in your notebook, just ask for the object representation.

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# To save it in a file

# %%
m.save('lex.html')

# %% [markdown]
# We can use different backgrounds, or tilesets.  Several are built in.  Options include Stamen Terrain, Stamen Toner, Mapbox Bright, and Mapbox Control room tiles.

# %%
m=folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Terrain',
    zoom_start=13
)
m.save('lex.html')

# %%
folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=13
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# Pick one you like and work with that for the rest of the class.

# %% [markdown]
# Folium also supports Cloudmade and Mapbox custom tilesets- simply pass your key to the API_key keyword.  These are services where you can buy more backgrounds to make your maps look nice.
#
# ```python
# folium.Map(location=[45.5236, -122.6750],
#            tiles='Mapbox',
#            API_key='your.API.key')
# ```

# %% [markdown]
# ### Open flights
#
# Let's go back to our openflight data and make some maps.

# %%
import pandas as pd
import numpy as np

# %%
# These files use \N as a missing value indicator.  When reading the CSVs, we will tell
# it to use that value as missing or NA.  The double backslash is required because
# otherwise it will interpret \N as a carriage return. 

# Read in the airports data.
airports = pd.read_csv("data/airports.dat", header=None, na_values='\\N')
airports.columns = ["id", "name", "city", "country", "iata", "icao", "latitude", "longitude", "altitude","timezone", "dst", "tz", "type", "source"]

# Read in the airlines data.
airlines = pd.read_csv("data/airlines.dat", header=None, na_values='\\N')
airlines.columns = ["id", "name", "alias", "iata", "icao", "callsign", "country", "active"]

# Read in the routes data.
routes = pd.read_csv("data/routes.dat", header=None, na_values='\\N')
routes.columns = ["airline", "airline_id", "source", "source_id", "dest", "dest_id", "codeshare", "stops", "equipment"]

# %%
# let's peek at what we have
airports.head()
# Out:
#    id                                         name          city  \
# 0   1                               Goroka Airport        Goroka
# 1   2                               Madang Airport        Madang
# 2   3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3   4                               Nadzab Airport        Nadzab
# 4   5  Port Moresby Jacksons International Airport  Port Moresby
#
#             country iata  icao  latitude   longitude  altitude  timezone dst  \
# 0  Papua New Guinea  GKA  AYGA -6.081690  145.391998      5282      10.0   U
# 1  Papua New Guinea  MAG  AYMD -5.207080  145.789001        20      10.0   U
# 2  Papua New Guinea  HGU  AYMH -5.826790  144.296005      5388      10.0   U
# 3  Papua New Guinea  LAE  AYNZ -6.569803  146.725977       239      10.0   U
# 4  Papua New Guinea  POM  AYPY -9.443380  147.220001       146      10.0   U
#
#                      tz     type       source
# 0  Pacific/Port_Moresby  airport  OurAirports
# 1  Pacific/Port_Moresby  airport  OurAirports
# 2  Pacific/Port_Moresby  airport  OurAirports
# 3  Pacific/Port_Moresby  airport  OurAirports
# 4  Pacific/Port_Moresby  airport  OurAirports

# %%
airlines.head()
# Out:
#    id                                          name alias iata icao callsign  \
# 0  -1                                       Unknown   NaN    -  NaN      NaN
# 1   1                                Private flight   NaN    -  NaN      NaN
# 2   2                                   135 Airways   NaN  NaN  GNL  GENERAL
# 3   3                                 1Time Airline   NaN   1T  RNX  NEXTIME
# 4   4  2 Sqn No 1 Elementary Flying Training School   NaN  NaN  WYT      NaN
#
#           country active
# 0             NaN      Y
# 1             NaN      Y
# 2   United States      N
# 3    South Africa      Y
# 4  United Kingdom      N

# %%
routes.head()
# Out:
#   airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 0      2B       410.0    AER     2965.0  KZN   2990.0       NaN      0
# 1      2B       410.0    ASF     2966.0  KZN   2990.0       NaN      0
# 2      2B       410.0    ASF     2966.0  MRV   2962.0       NaN      0
# 3      2B       410.0    CEK     2968.0  KZN   2990.0       NaN      0
# 4      2B       410.0    CEK     2968.0  OVB   4078.0       NaN      0
#
#   equipment
# 0       CR2
# 1       CR2
# 2       CR2
# 3       CR2
# 4       CR2

# %% [markdown]
# Make a worldwide map with the airports on it.

# %%
# Get a basic world map.
# 30 centers the map E-W, and 0 is the equator
airports_map = folium.Map(location=[30, 0], zoom_start=2)

# Loop through the airports, and draw each one as a marker on the map
# popup tells it what to display when you click on it
for name, row in airports.iterrows():
    
    # For some reason, this one airport causes issues with the map.
    if row["name"] != "South Pole Station":
        marker = folium.Marker([row["latitude"], row["longitude"]], popup=row['name'])
        marker.add_to(airports_map)
        
# Save it to a file (it's kinda big for the notebook)
airports_map.save('airports.html')

# %% [markdown]
# Hmm...it looks like there are airports everywhere!  Let's try again with smaller makers.
#
# We can also specify the color.  A list of custom colors is available here:
#
# http://www.w3schools.com/cssref/css_colors.asp

# %%
# over-write the airports_map, rather than just adding more markers to it. 
airports_map = folium.Map(location=[30, 0], zoom_start=2)

# use circle markers this time, with custom size and color
for name, row in airports.iterrows():
        
    # For some reason, this one airport causes issues with the map.
    if row["name"] != "South Pole Station":
        marker = folium.CircleMarker([row["latitude"], row["longitude"]], 
                                     radius=5,
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     popup=row['name'])
        marker.add_to(airports_map)
        
airports_map.save('airports.html')

# %% [markdown]
# You can also select icons to use as markers.  That code would look like:
#
#     marker = folium.Marker([row["latitude"], row["longitude"]],
#                            icon=folium.Icon(icon='cloud'),
#                            popup=row['name'])
#
# The list of icons comes from something called bootstrap, and can be found here:
#
# http://www.bootstrapicons.com/

# %% [markdown]
# Or you can use clusters of markers to clean up the map.  This will group them when you zoom out, similar to a Craigslist map.  You can see how to do that here:
#
# https://ocefpaf.github.io/python4oceanographers/blog/2015/12/14/geopandas_folium/
#
# You can clean up the rest of this airports map as part of your homework this week.

# %% [markdown]
# Let's draw the routes, but since we have lots, let's just start with the routes departing Lexington.

# %%
# Select the LEX routes, then join the source airports
lex_routes = routes[(routes['source']=="LEX")]
lex_routes = pd.merge(lex_routes, airports, left_on='source_id', right_on='id', how='left')
lexStops
# Out:
#    airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 0       9E      3976.0    LEX     4017.0  ATL   3682.0       NaN      0
# 1       AA        24.0    LEX     4017.0  CLT   3876.0         Y      0
# 2       AA        24.0    LEX     4017.0  DFW   3670.0         Y      0
# 3       AA        24.0    LEX     4017.0  ORD   3830.0         Y      0
# 6       DL      2009.0    LEX     4017.0  DCA   3520.0         Y      0
# 7       DL      2009.0    LEX     4017.0  DTW   3645.0         Y      0
# 8       DL      2009.0    LEX     4017.0  LGA   3697.0       NaN      0
# 9       DL      2009.0    LEX     4017.0  MSP   3858.0         Y      0
# 10      G4        35.0    LEX     4017.0  FLL   3533.0       NaN      0
# 11      G4        35.0    LEX     4017.0  PGD   7056.0       NaN      0
# 12      G4        35.0    LEX     4017.0  PIE   3617.0       NaN      0
# 13      G4        35.0    LEX     4017.0  SFB   4167.0       NaN      0
# 15      UA      5209.0    LEX     4017.0  IAH   3550.0         Y      0
#
#       equipment  id_source    ...      country_dest iata_dest icao_dest  \
# 0           CRJ       4017    ...     United States       ATL      KATL
# 1       CR7 CRJ       4017    ...     United States       CLT      KCLT
# 2       ERD ER4       4017    ...     United States       DFW      KDFW
# 3       ERD ER4       4017    ...     United States       ORD      KORD
# 6           CRJ       4017    ...     United States       DCA      KDCA
# 7   CR7 CRJ CR9       4017    ...     United States       DTW      KDTW
# 8           ERJ       4017    ...     United States       LGA      KLGA
# 9           CRJ       4017    ...     United States       MSP      KMSP
# 10          M80       4017    ...     United States       FLL      KFLL
# 11          M80       4017    ...     United States       PGD      KPGD
# 12          320       4017    ...     United States       PIE      KPIE
# 13      M80 320       4017    ...     United States       SFB      KSFB
# 15          ERJ       4017    ...     United States       IAH      KIAH
#
#    latitude_dest longitude_dest  altitude_dest  timezone_dest  dst_dest  \
# 0      33.636700     -84.428101           1026           -5.0         A
# 1      35.214001     -80.943100            748           -5.0         A
# 2      32.896801     -97.038002            607           -6.0         A
# 3      41.978600     -87.904800            672           -6.0         A
# 6      38.852100     -77.037697             15           -5.0         A
# 7      42.212399     -83.353401            645           -5.0         A
# 8      40.777199     -73.872597             21           -5.0         A
# 9      44.882000     -93.221802            841           -6.0         A
# 10     26.072599     -80.152702              9           -5.0         A
# 11     26.920200     -81.990501             26           -5.0         A
# 12     27.910200     -82.687401             11           -5.0         A
# 13     28.777599     -81.237503             55           -5.0         A
# 15     29.984400     -95.341400             97           -6.0         A
#
#              tz_dest type_dest
# 0   America/New_York   airport
# 1   America/New_York   airport
# 2    America/Chicago   airport
# 3    America/Chicago   airport
# 6   America/New_York   airport
# 7   America/New_York   airport
# 8   America/New_York   airport
# 9    America/Chicago   airport
# 10  America/New_York   airport
# 11  America/New_York   airport
# 12  America/New_York   airport
# 13  America/New_York   airport
# 15   America/Chicago   airport
#
# [13 rows x 35 columns]

# %%
oneStopLexStops=oneStopLex_routes.drop_duplicates(subset='dest')
a=1;
for dest, row in oneStopLexStops.iterrows():
    Intermediate_route_DB_twoStops=routes[(routes['source']==oneStopLexStops.dest[dest])]
    if a==1:
        twoStopLex_routes=pd.merge(Intermediate_route_DB_twoStops, airports, left_on='source_id', right_on='id', how='left')
    else:
        toAppendTwoStops=pd.merge(Intermediate_route_DB_twoStops, airports, left_on='source_id', right_on='id', how='left')
        twoStopLex_routes=pd.concat([twoStopLex_routes,toAppendTwoStops])
    a=a+1;
twoStopLex_routes.source_x.unique()
# Out:
# array(['LWB', 'MCN', 'MEI', 'MSL', 'PIB', 'TUP', 'AZO', 'CHA', 'CID',
#        'CRW', 'CVG', 'EVV', 'FWA', 'GSO', 'GSP', 'LAN', 'LEX', 'MBS',
#        'MSP', 'ROA', 'SYR', 'TYS', 'XNA', 'CLT', 'DFW', 'LHR', 'MIA',
#        'ORD', 'PHL', 'PHX', 'DEN', 'YYZ', 'ABE', 'ABQ', 'ABY', 'AEX',
#        'AGS', 'ALB', 'ATW', 'AUS', 'AVL', 'AVP', 'BDL', 'BHM', 'BMI',
#        'BNA', 'BOS', 'BQK', 'BRU', 'BTR', 'BTV', 'BUF', 'BWI', 'CAE',
#        'CAK', 'CDG', 'CHO', 'CHS', 'CLE', 'CMH', 'COS', 'CSG', 'CUN',
#        'CZM', 'DAB', 'DAL', 'DAY', 'DCA', 'DHN', 'DSM', 'DTW', 'DUB',
#        'DUS', 'ECP', 'ELP', 'EWN', 'EWR', 'EYW', 'FAY', 'FCO', 'FLL',
#        'FNT', 'FRA', 'FSM', 'GDL', 'GNV', 'GPT', 'GRB', 'GRK', 'GRR',
#        'GTR', 'HPN', 'HSV', 'IAD', 'IAH', 'ICT', 'ILM', 'IND', 'JAN',
#        'JAX', 'JFK', 'LAS', 'LAX', 'LFT', 'LGA', 'LIT', 'MAD', 'MAN',
#        'MCI', 'MCO', 'MDT', 'MDW', 'MEM', 'MEX', 'MGM', 'MHT', 'MKE',
#        'MLB', 'MLI', 'MLU', 'MOB', 'MSN', 'MSY', 'MTY', 'MUC', 'MYR',
#        'NAS', 'OAJ', 'OKC', 'OMA', 'ORF', 'PBI', 'PDX', 'PHF', 'PIA',
#        'PIT', 'PNS', 'PTY', 'PVD', 'PWM', 'RDU', 'RIC', 'ROC', 'RSW',
#        'SAN', 'SAT', 'SAV', 'SBN', 'SDF', 'SEA', 'SFO', 'SGF', 'SHV',
#        'SJO', 'SJU', 'SLC', 'SMF', 'SNA', 'SRQ', 'STL', 'STR', 'TLH',
#        'TPA', 'TRI', 'TUL', 'TUS', 'VLD', 'VPS', 'YUL', 'PVR', 'SJD',
#        'HOU', 'AMS', 'AUA', 'BDA', 'BJX', 'BOG', 'BON', 'BSB', 'BZE',
#        'CCS', 'DXB', 'EZE', 'FAR', 'FPO', 'FSD', 'GCM', 'GGT', 'GIG',
#        'GRU', 'GUA', 'HNL', 'ICN', 'JNB', 'KIN', 'LIM', 'LIR', 'LOS',
#        'MBJ', 'MGA', 'NRT', 'PAP', 'PLS', 'PUJ', 'RTB', 'SAL', 'SAP',
#        'SCL', 'SDQ', 'SJC', 'STT', 'SXM', 'TGU', 'UIO', 'UVF', 'ZRH',
#        'TTN', 'CUR', 'ANU', 'ATL', 'FLO', 'HHH', 'HTS', 'LYH', 'PGV',
#        'SBY', 'YOW', 'LUK', 'ABI', 'ACT', 'AGU', 'AMA', 'BNE', 'BPT',
#        'BRO', 'CLL', 'CMI', 'COU', 'CRP', 'CUU', 'DRO', 'FAT', 'GCK',
#        'GGG', 'GJT', 'GRI', 'JLN', 'LAW', 'LBB', 'LCH', 'LRD', 'MAF',
#        'MFE', 'MHK', 'MLM', 'MZT', 'OGG', 'ONT', 'PBC', 'PSP', 'QRO',
#        'RAP', 'RNO', 'ROW', 'SAF', 'SJT', 'SLP', 'SPS', 'TRC', 'TXK',
#        'TYR', 'YEG', 'YVR', 'YYC', 'ZCL', 'OAK', 'BRL', 'DEC', 'ALO',
#        'AMM', 'ART', 'AUH', 'CWA', 'DBQ', 'DOH', 'HKG', 'LSE', 'MQT',
#        'PEK', 'PVG', 'RST', 'SUX', 'TOL', 'TVC', 'TXL', 'YKF', 'YHZ',
#        'YQB', 'YQR', 'YWG', 'YXU', 'DEL', 'ANC', 'WAW', 'ACY', 'VIE',
#        'ARN', 'CPH', 'IST', 'BOI', 'BZN', 'CMX', 'DLH', 'EAU', 'ELM',
#        'FOE', 'LNK', 'MKG', 'PAH', 'SCE', 'STC', 'YXE', 'BGR', 'ISP',
#        'APN', 'BGM', 'CIU', 'ERI', 'ESC', 'ITH', 'NGO', 'PLN', 'SWF',
#        'ILG', 'ABR', 'BIL', 'BIS', 'BJI', 'BRD', 'DIK', 'FCA', 'GEG',
#        'GFK', 'GTF', 'HIB', 'HLN', 'IMT', 'INL', 'ISN', 'MOT', 'MSO',
#        'PSC', 'RHI', 'ATY', 'BIM', 'ELH', 'GHB', 'MHH', 'TCB', 'MDE',
#        'ORH', 'POS', 'OSL', 'PBG', 'AXM', 'BQN', 'CTG', 'IAG', 'LBE',
#        'STI', 'TLC', 'ZSA', 'RFD', 'YNG', 'LCK', 'KEF', 'BLV', 'CKB',
#        'HGR', 'OWB', 'PSM', 'VCT', 'DME', 'ACA', 'BFL', 'CME', 'DGO',
#        'HOB', 'HRL', 'HUX', 'MID', 'OAX', 'SLW', 'TAM', 'VER', 'VSA',
#        'ZIH', 'ZLO'], dtype=object)

# %%
lexStops=lex_routes.drop_duplicates(subset='dest')
a=1;
for dest, row in lexStops.iterrows():
    Intermediate_route_DB=routes[(routes['source']==lexStops.dest[dest])]
    if a==1:
        oneStopLex_routes=pd.merge(Intermediate_route_DB, airports, left_on='source_id', right_on='id', how='left')
    else:
        toAppend=pd.merge(Intermediate_route_DB, airports, left_on='source_id', right_on='id', how='left')
        oneStopLex_routes=pd.concat([oneStopLex_routes,toAppend])
    a=a+1;
oneStopLex_routes.source_x.unique()

# %%
twoStopLex_routes.count()
# Out:
# airline       26262
# airline_id    26207
# source_x      26262
# source_id     26262
# dest          26262
# dest_id       26232
# codeshare      8336
# stops         26262
# equipment     26248
# id            26073
# name          26073
# city          26073
# country       26073
# iata          26073
# icao          26073
# latitude      26073
# longitude     26073
# altitude      26073
# timezone      26073
# dst           26073
# tz            26073
# type          26073
# source_y      26073
# dtype: int64

# %%
oneStopLex_routes.count()
# Out:
# airline       3558
# airline_id    3557
# source_x      3558
# source_id     3558
# dest          3558
# dest_id       3558
# codeshare     1637
# stops         3558
# equipment     3552
# id            3558
# name          3558
# city          3558
# country       3558
# iata          3558
# icao          3558
# latitude      3558
# longitude     3558
# altitude      3558
# timezone      3558
# dst           3558
# tz            3558
# type          3558
# source_y      3558
# dtype: int64

# %%
# join the destination airports.  Here we need to use the suffixes option, because 
# the column names overlap, and we want to distinguish between source and dest
lex_routes = pd.merge(lex_routes, airports, 
                      left_on='dest_id', 
                      right_on='id', 
                      how='left', 
                      suffixes=['_source','_dest'])
lex_routes
# Out:
#    airline  airline_id source_x  source_id dest  dest_id codeshare  stops  \
# 0       9E      3976.0      LEX     4017.0  ATL   3682.0       NaN      0
# 1       AA        24.0      LEX     4017.0  CLT   3876.0         Y      0
# 2       AA        24.0      LEX     4017.0  DFW   3670.0         Y      0
# 3       AA        24.0      LEX     4017.0  ORD   3830.0         Y      0
# 4       AF       137.0      LEX     4017.0  ATL   3682.0         Y      0
# 5       DL      2009.0      LEX     4017.0  ATL   3682.0       NaN      0
# 6       DL      2009.0      LEX     4017.0  DCA   3520.0         Y      0
# 7       DL      2009.0      LEX     4017.0  DTW   3645.0         Y      0
# 8       DL      2009.0      LEX     4017.0  LGA   3697.0       NaN      0
# 9       DL      2009.0      LEX     4017.0  MSP   3858.0         Y      0
# 10      G4        35.0      LEX     4017.0  FLL   3533.0       NaN      0
# 11      G4        35.0      LEX     4017.0  PGD   7056.0       NaN      0
# 12      G4        35.0      LEX     4017.0  PIE   3617.0       NaN      0
# 13      G4        35.0      LEX     4017.0  SFB   4167.0       NaN      0
# 14      KL      3090.0      LEX     4017.0  ATL   3682.0         Y      0
# 15      UA      5209.0      LEX     4017.0  IAH   3550.0         Y      0
# 16      UA      5209.0      LEX     4017.0  ORD   3830.0         Y      0
# 17      US      5265.0      LEX     4017.0  CLT   3876.0       NaN      0
# 18      US      5265.0      LEX     4017.0  DFW   3670.0       NaN      0
# 19      US      5265.0      LEX     4017.0  ORD   3830.0         Y      0
#
#       equipment  id_source     ...      iata  icao   latitude  longitude  \
# 0           CRJ       4017     ...       ATL  KATL  33.636700 -84.428101
# 1       CR7 CRJ       4017     ...       CLT  KCLT  35.214001 -80.943100
# 2       ERD ER4       4017     ...       DFW  KDFW  32.896801 -97.038002
# 3       ERD ER4       4017     ...       ORD  KORD  41.978600 -87.904800
# 4       CRJ CR9       4017     ...       ATL  KATL  33.636700 -84.428101
# 5       M88 717       4017     ...       ATL  KATL  33.636700 -84.428101
# 6           CRJ       4017     ...       DCA  KDCA  38.852100 -77.037697
# 7   CR7 CRJ CR9       4017     ...       DTW  KDTW  42.212399 -83.353401
# 8           ERJ       4017     ...       LGA  KLGA  40.777199 -73.872597
# 9           CRJ       4017     ...       MSP  KMSP  44.882000 -93.221802
# 10          M80       4017     ...       FLL  KFLL  26.072599 -80.152702
# 11          M80       4017     ...       PGD  KPGD  26.920200 -81.990501
# 12          320       4017     ...       PIE  KPIE  27.910200 -82.687401
# 13      M80 320       4017     ...       SFB  KSFB  28.777599 -81.237503
# 14      CR9 CRJ       4017     ...       ATL  KATL  33.636700 -84.428101
# 15          ERJ       4017     ...       IAH  KIAH  29.984400 -95.341400
# 16      ERJ CRJ       4017     ...       ORD  KORD  41.978600 -87.904800
# 17          CR7       4017     ...       CLT  KCLT  35.214001 -80.943100
# 18          ERD       4017     ...       DFW  KDFW  32.896801 -97.038002
# 19      ERD ER4       4017     ...       ORD  KORD  41.978600 -87.904800
#
#    altitude  timezone  dst                tz     type  source_dest
# 0      1026      -5.0    A  America/New_York  airport  OurAirports
# 1       748      -5.0    A  America/New_York  airport  OurAirports
# 2       607      -6.0    A   America/Chicago  airport  OurAirports
# 3       672      -6.0    A   America/Chicago  airport  OurAirports
# 4      1026      -5.0    A  America/New_York  airport  OurAirports
# 5      1026      -5.0    A  America/New_York  airport  OurAirports
# 6        15      -5.0    A  America/New_York  airport  OurAirports
# 7       645      -5.0    A  America/New_York  airport  OurAirports
# 8        21      -5.0    A  America/New_York  airport  OurAirports
# 9       841      -6.0    A   America/Chicago  airport  OurAirports
# 10        9      -5.0    A  America/New_York  airport  OurAirports
# 11       26      -5.0    A  America/New_York  airport  OurAirports
# 12       11      -5.0    A  America/New_York  airport  OurAirports
# 13       55      -5.0    A  America/New_York  airport  OurAirports
# 14     1026      -5.0    A  America/New_York  airport  OurAirports
# 15       97      -6.0    A   America/Chicago  airport  OurAirports
# 16      672      -6.0    A   America/Chicago  airport  OurAirports
# 17      748      -5.0    A  America/New_York  airport  OurAirports
# 18      607      -6.0    A   America/Chicago  airport  OurAirports
# 19      672      -6.0    A   America/Chicago  airport  OurAirports
#
# [20 rows x 51 columns]

# %%
twoStopLex_routes
# Out:
#    airline  airline_id source_x  source_id dest  dest_id codeshare  stops  \
# 0       3M     20710.0      LWB     6958.0  ATL   3682.0       NaN      0
# 1       UA      5209.0      LWB     6958.0  IAD   3714.0         Y      0
# 0       3M     20710.0      MCN     3754.0  ATL   3682.0       NaN      0
# 1       3M     20710.0      MCN     3754.0  MCO   3878.0       NaN      0
# 0       3M     20710.0      MEI     4335.0  ATL   3682.0       NaN      0
# 0       3M     20710.0      MSL     5756.0  ATL   3682.0       NaN      0
# 0       3M     20710.0      PIB     5759.0  ATL   3682.0       NaN      0
# 0       3M     20710.0      TUP     5773.0  ATL   3682.0       NaN      0
# 1       3M     20710.0      TUP     5773.0  GLH   6130.0       NaN      0
# 0       9E      3976.0      AZO     4039.0  ATL   3682.0       NaN      0
# 1       AA        24.0      AZO     4039.0  ORD   3830.0         Y      0
# 2       DL      2009.0      AZO     4039.0  ATL   3682.0         Y      0
# 3       DL      2009.0      AZO     4039.0  DTW   3645.0       NaN      0
# 4       DL      2009.0      AZO     4039.0  MSP   3858.0         Y      0
# 5       US      5265.0      AZO     4039.0  ORD   3830.0         Y      0
# 0       9E      3976.0      CHA     3578.0  ATL   3682.0       NaN      0
# 1       AA        24.0      CHA     3578.0  CLT   3876.0       NaN      0
# 2       AA        24.0      CHA     3578.0  DCA   3520.0         Y      0
# 3       AA        24.0      CHA     3578.0  DFW   3670.0         Y      0
# 4       AA        24.0      CHA     3578.0  ORD   3830.0         Y      0
# 5       AF       137.0      CHA     3578.0  ATL   3682.0         Y      0
# 6       AZ       596.0      CHA     3578.0  ATL   3682.0         Y      0
# 7       DL      2009.0      CHA     3578.0  ATL   3682.0       NaN      0
# 8       DL      2009.0      CHA     3578.0  DTW   3645.0         Y      0
# 9       G4        35.0      CHA     3578.0  PIE   3617.0       NaN      0
# 10      G4        35.0      CHA     3578.0  SFB   4167.0       NaN      0
# 11      KL      3090.0      CHA     3578.0  ATL   3682.0         Y      0
# 12      US      5265.0      CHA     3578.0  CLT   3876.0         Y      0
# 13      US      5265.0      CHA     3578.0  DCA   3520.0         Y      0
# 14      US      5265.0      CHA     3578.0  DFW   3670.0       NaN      0
# ..     ...         ...      ...        ...  ...      ...       ...    ...
# 15      Y4      5325.0      VER     1854.0  TIJ   1847.0       NaN      0
# 0       4O     17885.0      VSA     1853.0  MEX   1824.0       NaN      0
# 1       7M     16615.0      VSA     1853.0  MID   1819.0       NaN      0
# 2       7M     16615.0      VSA     1853.0  VER   1854.0       NaN      0
# 3       AM       321.0      VSA     1853.0  MEX   1824.0       NaN      0
# 4       AM       321.0      VSA     1853.0  MID   1819.0       NaN      0
# 5       AM       321.0      VSA     1853.0  PAZ   1830.0       NaN      0
# 6       AM       321.0      VSA     1853.0  VER   1854.0       NaN      0
# 7       DL      2009.0      VSA     1853.0  MEX   1824.0         Y      0
# 8       UA      5209.0      VSA     1853.0  IAH   3550.0         Y      0
# 9       VB     10646.0      VSA     1853.0  CUN   1852.0       NaN      0
# 10      VB     10646.0      VSA     1853.0  GDL   1804.0       NaN      0
# 11      VB     10646.0      VSA     1853.0  MTY   1825.0       NaN      0
# 12      VW      1290.0      VSA     1853.0  PAZ   1830.0       NaN      0
# 0       4O     17885.0      ZIH     1856.0  MEX   1824.0       NaN      0
# 1       4O     17885.0      ZIH     1856.0  TLC   1850.0       NaN      0
# 2       AA        24.0      ZIH     1856.0  PHX   3462.0       NaN      0
# 3       AM       321.0      ZIH     1856.0  LAX   3484.0         Y      0
# 4       AM       321.0      ZIH     1856.0  MEX   1824.0         Y      0
# 5       AS       439.0      ZIH     1856.0  LAX   3484.0       NaN      0
# 6       UA      5209.0      ZIH     1856.0  IAH   3550.0         Y      0
# 7       US      5265.0      ZIH     1856.0  PHX   3462.0       NaN      0
# 8       VW      1290.0      ZIH     1856.0  MEX   1824.0       NaN      0
# 0       4O     17885.0      ZLO     1858.0  MEX   1824.0       NaN      0
# 1       AM       321.0      ZLO     1858.0  LAX   3484.0         Y      0
# 2       AM       321.0      ZLO     1858.0  MEX   1824.0         Y      0
# 3       AS       439.0      ZLO     1858.0  LAX   3484.0       NaN      0
# 4       UA      5209.0      ZLO     1858.0  IAH   3550.0         Y      0
# 5       VW      1290.0      ZLO     1858.0  MEX   1824.0       NaN      0
# 6       Y4      5325.0      ZLO     1858.0  TIJ   1847.0       NaN      0
#
#           equipment      id     ...      iata  icao   latitude   longitude  \
# 0               SF3  6958.0     ...       LWB  KLWB  37.858299  -80.399498
# 1               SF3  6958.0     ...       LWB  KLWB  37.858299  -80.399498
# 0               SF3  3754.0     ...       MCN  KMCN  32.692799  -83.649200
# 1               SF3  3754.0     ...       MCN  KMCN  32.692799  -83.649200
# 0               SF3  4335.0     ...       MEI  KMEI  32.332600  -88.751900
# 0               SF3  5756.0     ...       MSL  KMSL  34.745300  -87.610199
# 0              SF3   5759.0     ...       PIB  KPIB  31.467100  -89.337097
# 0              SF3   5773.0     ...       TUP  KTUP  34.268101  -88.769897
# 1               SF3  5773.0     ...       TUP  KTUP  34.268101  -88.769897
# 0               CRJ  4039.0     ...       AZO  KAZO  42.234901  -85.552101
# 1           ER4 ERD  4039.0     ...       AZO  KAZO  42.234901  -85.552101
# 2               CRJ  4039.0     ...       AZO  KAZO  42.234901  -85.552101
# 3               ERJ  4039.0     ...       AZO  KAZO  42.234901  -85.552101
# 4               CRJ  4039.0     ...       AZO  KAZO  42.234901  -85.552101
# 5           ER4 ERD  4039.0     ...       AZO  KAZO  42.234901  -85.552101
# 0               CRJ  3578.0     ...       CHA  KCHA  35.035301  -85.203796
# 1           CRJ DH8  3578.0     ...       CHA  KCHA  35.035301  -85.203796
# 2               CRJ  3578.0     ...       CHA  KCHA  35.035301  -85.203796
# 3           ER4 ERD  3578.0     ...       CHA  KCHA  35.035301  -85.203796
# 4           ER4 ERD  3578.0     ...       CHA  KCHA  35.035301  -85.203796
# 5               CRJ  3578.0     ...       CHA  KCHA  35.035301  -85.203796
# 6           CRJ CR7  3578.0     ...       CHA  KCHA  35.035301  -85.203796
# 7               M88  3578.0     ...       CHA  KCHA  35.035301  -85.203796
# 8               CRJ  3578.0     ...       CHA  KCHA  35.035301  -85.203796
# 9               320  3578.0     ...       CHA  KCHA  35.035301  -85.203796
# 10              M80  3578.0     ...       CHA  KCHA  35.035301  -85.203796
# 11              CRJ  3578.0     ...       CHA  KCHA  35.035301  -85.203796
# 12          CRJ DH3  3578.0     ...       CHA  KCHA  35.035301  -85.203796
# 13              CRJ  3578.0     ...       CHA  KCHA  35.035301  -85.203796
# 14              ERD  3578.0     ...       CHA  KCHA  35.035301  -85.203796
# ..              ...     ...     ...       ...   ...        ...         ...
# 15              320  1854.0     ...       VER  MMVR  19.145901  -96.187302
# 0               320  1853.0     ...       VSA  MMVA  17.997000  -92.817398
# 1               D28  1853.0     ...       VSA  MMVA  17.997000  -92.817398
# 2               D28  1853.0     ...       VSA  MMVA  17.997000  -92.817398
# 3   737 EMJ ERJ E70  1853.0     ...       VSA  MMVA  17.997000  -92.817398
# 4               AT7  1853.0     ...       VSA  MMVA  17.997000  -92.817398
# 5               ATR  1853.0     ...       VSA  MMVA  17.997000  -92.817398
# 6               AT7  1853.0     ...       VSA  MMVA  17.997000  -92.817398
# 7               737  1853.0     ...       VSA  MMVA  17.997000  -92.817398
# 8               CR7  1853.0     ...       VSA  MMVA  17.997000  -92.817398
# 9               733  1853.0     ...       VSA  MMVA  17.997000  -92.817398
# 10              733  1853.0     ...       VSA  MMVA  17.997000  -92.817398
# 11              733  1853.0     ...       VSA  MMVA  17.997000  -92.817398
# 12              ATR  1853.0     ...       VSA  MMVA  17.997000  -92.817398
# 0               320  1856.0     ...       ZIH  MMZH  17.601601 -101.460999
# 1               320  1856.0     ...       ZIH  MMZH  17.601601 -101.460999
# 2               320  1856.0     ...       ZIH  MMZH  17.601601 -101.460999
# 3               739  1856.0     ...       ZIH  MMZH  17.601601 -101.460999
# 4           ERJ EMJ  1856.0     ...       ZIH  MMZH  17.601601 -101.460999
# 5               739  1856.0     ...       ZIH  MMZH  17.601601 -101.460999
# 6               ERJ  1856.0     ...       ZIH  MMZH  17.601601 -101.460999
# 7               320  1856.0     ...       ZIH  MMZH  17.601601 -101.460999
# 8               ATR  1856.0     ...       ZIH  MMZH  17.601601 -101.460999
# 0               SU9  1858.0     ...       ZLO  MMZO  19.144800 -104.558998
# 1               73H  1858.0     ...       ZLO  MMZO  19.144800 -104.558998
# 2           E75 ERJ  1858.0     ...       ZLO  MMZO  19.144800 -104.558998
# 3               73H  1858.0     ...       ZLO  MMZO  19.144800 -104.558998
# 4               ERJ  1858.0     ...       ZLO  MMZO  19.144800 -104.558998
# 5               ATR  1858.0     ...       ZLO  MMZO  19.144800 -104.558998
# 6               319  1858.0     ...       ZLO  MMZO  19.144800 -104.558998
#
#    altitude  timezone  dst                   tz     type     source_y
# 0    2302.0      -5.0    U     America/New_York  airport  OurAirports
# 1    2302.0      -5.0    U     America/New_York  airport  OurAirports
# 0     354.0      -5.0    A     America/New_York  airport  OurAirports
# 1     354.0      -5.0    A     America/New_York  airport  OurAirports
# 0     297.0      -6.0    A      America/Chicago  airport  OurAirports
# 0     551.0      -6.0    A      America/Chicago  airport  OurAirports
# 0     298.0      -6.0    A      America/Chicago  airport  OurAirports
# 0     346.0      -6.0    A      America/Chicago  airport  OurAirports
# 1     346.0      -6.0    A      America/Chicago  airport  OurAirports
# 0     874.0      -5.0    A     America/New_York  airport  OurAirports
# 1     874.0      -5.0    A     America/New_York  airport  OurAirports
# 2     874.0      -5.0    A     America/New_York  airport  OurAirports
# 3     874.0      -5.0    A     America/New_York  airport  OurAirports
# 4     874.0      -5.0    A     America/New_York  airport  OurAirports
# 5     874.0      -5.0    A     America/New_York  airport  OurAirports
# 0     683.0      -5.0    A     America/New_York  airport  OurAirports
# 1     683.0      -5.0    A     America/New_York  airport  OurAirports
# 2     683.0      -5.0    A     America/New_York  airport  OurAirports
# 3     683.0      -5.0    A     America/New_York  airport  OurAirports
# 4     683.0      -5.0    A     America/New_York  airport  OurAirports
# 5     683.0      -5.0    A     America/New_York  airport  OurAirports
# 6     683.0      -5.0    A     America/New_York  airport  OurAirports
# 7     683.0      -5.0    A     America/New_York  airport  OurAirports
# 8     683.0      -5.0    A     America/New_York  airport  OurAirports
# 9     683.0      -5.0    A     America/New_York  airport  OurAirports
# 10    683.0      -5.0    A     America/New_York  airport  OurAirports
# 11    683.0      -5.0    A     America/New_York  airport  OurAirports
# 12    683.0      -5.0    A     America/New_York  airport  OurAirports
# 13    683.0      -5.0    A     America/New_York  airport  OurAirports
# 14    683.0      -5.0    A     America/New_York  airport  OurAirports
# ..      ...       ...  ...                  ...      ...          ...
# 15     90.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 0      46.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 1      46.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 2      46.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 3      46.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 4      46.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 5      46.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 6      46.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 7      46.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 8      46.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 9      46.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 10     46.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 11     46.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 12     46.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 0      26.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 1      26.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 2      26.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 3      26.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 4      26.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 5      26.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 6      26.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 7      26.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 8      26.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 0      30.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 1      30.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 2      30.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 3      30.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 4      30.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 5      30.0      -6.0    S  America/Mexico_City  airport  OurAirports
# 6      30.0      -6.0    S  America/Mexico_City  airport  OurAirports
#
# [26262 rows x 23 columns]

# %%
oneStopLex_routes
# Out:
#     airline  airline_id source_x  source_id dest  dest_id codeshare  stops  \
# 0        3M     20710.0      ATL     3682.0  LWB   6958.0       NaN      0
# 1        3M     20710.0      ATL     3682.0  MCN   3754.0       NaN      0
# 2        3M     20710.0      ATL     3682.0  MEI   4335.0       NaN      0
# 3        3M     20710.0      ATL     3682.0  MSL   5756.0       NaN      0
# 4        3M     20710.0      ATL     3682.0  PIB   5759.0       NaN      0
# 5        3M     20710.0      ATL     3682.0  TUP   5773.0       NaN      0
# 6        9E      3976.0      ATL     3682.0  AZO   4039.0       NaN      0
# 7        9E      3976.0      ATL     3682.0  CHA   3578.0       NaN      0
# 8        9E      3976.0      ATL     3682.0  CID   4043.0       NaN      0
# 9        9E      3976.0      ATL     3682.0  CRW   4285.0       NaN      0
# 10       9E      3976.0      ATL     3682.0  CVG   3488.0       NaN      0
# 11       9E      3976.0      ATL     3682.0  EVV   4018.0       NaN      0
# 12       9E      3976.0      ATL     3682.0  FWA   4041.0       NaN      0
# 13       9E      3976.0      ATL     3682.0  GSO   4008.0       NaN      0
# 14       9E      3976.0      ATL     3682.0  GSP   4034.0       NaN      0
# 15       9E      3976.0      ATL     3682.0  LAN   3544.0       NaN      0
# 16       9E      3976.0      ATL     3682.0  LEX   4017.0       NaN      0
# 17       9E      3976.0      ATL     3682.0  MBS   4128.0       NaN      0
# 18       9E      3976.0      ATL     3682.0  MSP   3858.0       NaN      0
# 19       9E      3976.0      ATL     3682.0  ROA   4016.0       NaN      0
# 20       9E      3976.0      ATL     3682.0  SYR   3745.0       NaN      0
# 21       9E      3976.0      ATL     3682.0  TYS   3676.0       NaN      0
# 22       9E      3976.0      ATL     3682.0  XNA   4356.0       NaN      0
# 23       AA        24.0      ATL     3682.0  CLT   3876.0         Y      0
# 24       AA        24.0      ATL     3682.0  DFW   3670.0       NaN      0
# 25       AA        24.0      ATL     3682.0  LHR    507.0         Y      0
# 26       AA        24.0      ATL     3682.0  MIA   3576.0       NaN      0
# 27       AA        24.0      ATL     3682.0  ORD   3830.0         Y      0
# 28       AA        24.0      ATL     3682.0  PHL   3752.0         Y      0
# 29       AA        24.0      ATL     3682.0  PHX   3462.0         Y      0
# ..      ...         ...      ...        ...  ...      ...       ...    ...
# 213      UA      5209.0      IAH     3550.0  TUL   3855.0         Y      0
# 214      UA      5209.0      IAH     3550.0  TUS   3636.0         Y      0
# 215      UA      5209.0      IAH     3550.0  TYR   3848.0         Y      0
# 216      UA      5209.0      IAH     3550.0  TYS   3676.0         Y      0
# 217      UA      5209.0      IAH     3550.0  UIO   2688.0       NaN      0
# 218      UA      5209.0      IAH     3550.0  VER   1854.0         Y      0
# 219      UA      5209.0      IAH     3550.0  VPS   3873.0         Y      0
# 220      UA      5209.0      IAH     3550.0  VSA   1853.0         Y      0
# 221      UA      5209.0      IAH     3550.0  XNA   4356.0         Y      0
# 222      UA      5209.0      IAH     3550.0  YEG     49.0       NaN      0
# 223      UA      5209.0      IAH     3550.0  YUL    146.0         Y      0
# 224      UA      5209.0      IAH     3550.0  YVR    156.0       NaN      0
# 225      UA      5209.0      IAH     3550.0  YYC    178.0       NaN      0
# 226      UA      5209.0      IAH     3550.0  YYZ    193.0         Y      0
# 227      UA      5209.0      IAH     3550.0  ZIH   1856.0         Y      0
# 228      UA      5209.0      IAH     3550.0  ZLO   1858.0         Y      0
# 229      UN      5067.0      IAH     3550.0  DME   4029.0         Y      0
# 230      US      5265.0      IAH     3550.0  CLT   3876.0       NaN      0
# 231      US      5265.0      IAH     3550.0  DFW   3670.0       NaN      0
# 232      US      5265.0      IAH     3550.0  DOH  11051.0       NaN      0
# 233      US      5265.0      IAH     3550.0  IST   1701.0       NaN      0
# 234      US      5265.0      IAH     3550.0  LAX   3484.0       NaN      0
# 235      US      5265.0      IAH     3550.0  MIA   3576.0       NaN      0
# 236      US      5265.0      IAH     3550.0  ORD   3830.0       NaN      0
# 237      US      5265.0      IAH     3550.0  PHL   3752.0       NaN      0
# 238      US      5265.0      IAH     3550.0  PHX   3462.0       NaN      0
# 239      US      5265.0      IAH     3550.0  SAL   1892.0       NaN      0
# 240      VA      5360.0      IAH     3550.0  ATL   3682.0         Y      0
# 241      VB     10646.0      IAH     3550.0  MTY   1825.0       NaN      0
# 242      VS      5347.0      IAH     3550.0  ATL   3682.0         Y      0
#
#                equipment    id     ...      iata  icao latitude  longitude  \
# 0                    SF3  3682     ...       ATL  KATL  33.6367 -84.428101
# 1                    SF3  3682     ...       ATL  KATL  33.6367 -84.428101
# 2                    SF3  3682     ...       ATL  KATL  33.6367 -84.428101
# 3                    SF3  3682     ...       ATL  KATL  33.6367 -84.428101
# 4                    SF3  3682     ...       ATL  KATL  33.6367 -84.428101
# 5                    SF3  3682     ...       ATL  KATL  33.6367 -84.428101
# 6                    CRJ  3682     ...       ATL  KATL  33.6367 -84.428101
# 7                    CRJ  3682     ...       ATL  KATL  33.6367 -84.428101
# 8                    CRJ  3682     ...       ATL  KATL  33.6367 -84.428101
# 9                    CRJ  3682     ...       ATL  KATL  33.6367 -84.428101
# 10                  CR9   3682     ...       ATL  KATL  33.6367 -84.428101
# 11                   CRJ  3682     ...       ATL  KATL  33.6367 -84.428101
# 12                   CRJ  3682     ...       ATL  KATL  33.6367 -84.428101
# 13                   CR9  3682     ...       ATL  KATL  33.6367 -84.428101
# 14                   CRJ  3682     ...       ATL  KATL  33.6367 -84.428101
# 15                   CRJ  3682     ...       ATL  KATL  33.6367 -84.428101
# 16                   CRJ  3682     ...       ATL  KATL  33.6367 -84.428101
# 17                   CRJ  3682     ...       ATL  KATL  33.6367 -84.428101
# 18                   NaN  3682     ...       ATL  KATL  33.6367 -84.428101
# 19                   CRJ  3682     ...       ATL  KATL  33.6367 -84.428101
# 20                   CR9  3682     ...       ATL  KATL  33.6367 -84.428101
# 21               CRJ CR9  3682     ...       ATL  KATL  33.6367 -84.428101
# 22                   CRJ  3682     ...       ATL  KATL  33.6367 -84.428101
# 23       319 320 CR9 321  3682     ...       ATL  KATL  33.6367 -84.428101
# 24           M80 319 M83  3682     ...       ATL  KATL  33.6367 -84.428101
# 25                   777  3682     ...       ATL  KATL  33.6367 -84.428101
# 26                   738  3682     ...       ATL  KATL  33.6367 -84.428101
# 27               CR7 E75  3682     ...       ATL  KATL  33.6367 -84.428101
# 28   E75 E90 319 CRJ E70  3682     ...       ATL  KATL  33.6367 -84.428101
# 29               320 321  3682     ...       ATL  KATL  33.6367 -84.428101
# ..                   ...   ...     ...       ...   ...      ...        ...
# 213          CRJ ERJ CR7  3550     ...       IAH  KIAH  29.9844 -95.341400
# 214              ERJ CR7  3550     ...       IAH  KIAH  29.9844 -95.341400
# 215                  ERJ  3550     ...       IAH  KIAH  29.9844 -95.341400
# 216                  ERJ  3550     ...       IAH  KIAH  29.9844 -95.341400
# 217              73G 738  3550     ...       IAH  KIAH  29.9844 -95.341400
# 218                  ERJ  3550     ...       IAH  KIAH  29.9844 -95.341400
# 219                  ERJ  3550     ...       IAH  KIAH  29.9844 -95.341400
# 220                  CR7  3550     ...       IAH  KIAH  29.9844 -95.341400
# 221              CRJ ERJ  3550     ...       IAH  KIAH  29.9844 -95.341400
# 222      738 320 73G 319  3550     ...       IAH  KIAH  29.9844 -95.341400
# 223                  E70  3550     ...       IAH  KIAH  29.9844 -95.341400
# 224          320 319 739  3550     ...       IAH  KIAH  29.9844 -95.341400
# 225          738 320 739  3550     ...       IAH  KIAH  29.9844 -95.341400
# 226          CRA ERJ CR7  3550     ...       IAH  KIAH  29.9844 -95.341400
# 227                  ERJ  3550     ...       IAH  KIAH  29.9844 -95.341400
# 228                  ERJ  3550     ...       IAH  KIAH  29.9844 -95.341400
# 229                  77W  3550     ...       IAH  KIAH  29.9844 -95.341400
# 230      321 734 319 320  3550     ...       IAH  KIAH  29.9844 -95.341400
# 231              M80 M83  3550     ...       IAH  KIAH  29.9844 -95.341400
# 232                  77L  3550     ...       IAH  KIAH  29.9844 -95.341400
# 233                  77W  3550     ...       IAH  KIAH  29.9844 -95.341400
# 234                  CR7  3550     ...       IAH  KIAH  29.9844 -95.341400
# 235                  738  3550     ...       IAH  KIAH  29.9844 -95.341400
# 236                  CR7  3550     ...       IAH  KIAH  29.9844 -95.341400
# 237                  E90  3550     ...       IAH  KIAH  29.9844 -95.341400
# 238              319 320  3550     ...       IAH  KIAH  29.9844 -95.341400
# 239                  E90  3550     ...       IAH  KIAH  29.9844 -95.341400
# 240          M88 717 319  3550     ...       IAH  KIAH  29.9844 -95.341400
# 241                  733  3550     ...       IAH  KIAH  29.9844 -95.341400
# 242          M88 717 319  3550     ...       IAH  KIAH  29.9844 -95.341400
#
#     altitude  timezone  dst                tz     type     source_y
# 0       1026      -5.0    A  America/New_York  airport  OurAirports
# 1       1026      -5.0    A  America/New_York  airport  OurAirports
# 2       1026      -5.0    A  America/New_York  airport  OurAirports
# 3       1026      -5.0    A  America/New_York  airport  OurAirports
# 4       1026      -5.0    A  America/New_York  airport  OurAirports
# 5       1026      -5.0    A  America/New_York  airport  OurAirports
# 6       1026      -5.0    A  America/New_York  airport  OurAirports
# 7       1026      -5.0    A  America/New_York  airport  OurAirports
# 8       1026      -5.0    A  America/New_York  airport  OurAirports
# 9       1026      -5.0    A  America/New_York  airport  OurAirports
# 10      1026      -5.0    A  America/New_York  airport  OurAirports
# 11      1026      -5.0    A  America/New_York  airport  OurAirports
# 12      1026      -5.0    A  America/New_York  airport  OurAirports
# 13      1026      -5.0    A  America/New_York  airport  OurAirports
# 14      1026      -5.0    A  America/New_York  airport  OurAirports
# 15      1026      -5.0    A  America/New_York  airport  OurAirports
# 16      1026      -5.0    A  America/New_York  airport  OurAirports
# 17      1026      -5.0    A  America/New_York  airport  OurAirports
# 18      1026      -5.0    A  America/New_York  airport  OurAirports
# 19      1026      -5.0    A  America/New_York  airport  OurAirports
# 20      1026      -5.0    A  America/New_York  airport  OurAirports
# 21      1026      -5.0    A  America/New_York  airport  OurAirports
# 22      1026      -5.0    A  America/New_York  airport  OurAirports
# 23      1026      -5.0    A  America/New_York  airport  OurAirports
# 24      1026      -5.0    A  America/New_York  airport  OurAirports
# 25      1026      -5.0    A  America/New_York  airport  OurAirports
# 26      1026      -5.0    A  America/New_York  airport  OurAirports
# 27      1026      -5.0    A  America/New_York  airport  OurAirports
# 28      1026      -5.0    A  America/New_York  airport  OurAirports
# 29      1026      -5.0    A  America/New_York  airport  OurAirports
# ..       ...       ...  ...               ...      ...          ...
# 213       97      -6.0    A   America/Chicago  airport  OurAirports
# 214       97      -6.0    A   America/Chicago  airport  OurAirports
# 215       97      -6.0    A   America/Chicago  airport  OurAirports
# 216       97      -6.0    A   America/Chicago  airport  OurAirports
# 217       97      -6.0    A   America/Chicago  airport  OurAirports
# 218       97      -6.0    A   America/Chicago  airport  OurAirports
# 219       97      -6.0    A   America/Chicago  airport  OurAirports
# 220       97      -6.0    A   America/Chicago  airport  OurAirports
# 221       97      -6.0    A   America/Chicago  airport  OurAirports
# 222       97      -6.0    A   America/Chicago  airport  OurAirports
# 223       97      -6.0    A   America/Chicago  airport  OurAirports
# 224       97      -6.0    A   America/Chicago  airport  OurAirports
# 225       97      -6.0    A   America/Chicago  airport  OurAirports
# 226       97      -6.0    A   America/Chicago  airport  OurAirports
# 227       97      -6.0    A   America/Chicago  airport  OurAirports
# 228       97      -6.0    A   America/Chicago  airport  OurAirports
# 229       97      -6.0    A   America/Chicago  airport  OurAirports
# 230       97      -6.0    A   America/Chicago  airport  OurAirports
# 231       97      -6.0    A   America/Chicago  airport  OurAirports
# 232       97      -6.0    A   America/Chicago  airport  OurAirports
# 233       97      -6.0    A   America/Chicago  airport  OurAirports
# 234       97      -6.0    A   America/Chicago  airport  OurAirports
# 235       97      -6.0    A   America/Chicago  airport  OurAirports
# 236       97      -6.0    A   America/Chicago  airport  OurAirports
# 237       97      -6.0    A   America/Chicago  airport  OurAirports
# 238       97      -6.0    A   America/Chicago  airport  OurAirports
# 239       97      -6.0    A   America/Chicago  airport  OurAirports
# 240       97      -6.0    A   America/Chicago  airport  OurAirports
# 241       97      -6.0    A   America/Chicago  airport  OurAirports
# 242       97      -6.0    A   America/Chicago  airport  OurAirports
#
# [3558 rows x 23 columns]

# %%
# join the destination airports.  Here we need to use the suffixes option, because 
# the column names overlap, and we want to distinguish between source and dest
twoStopLex_routes = pd.merge(twoStopLex_routes, airports, 
                      left_on='dest_id', 
                      right_on='id', 
                      how='left', 
                      suffixes=['_source','_dest'])
twoStopLex_routes
# Out:
#       airline  airline_id source_x  source_id dest  dest_id codeshare  stops  \
# 0          3M     20710.0      LWB     6958.0  ATL   3682.0       NaN      0
# 1          UA      5209.0      LWB     6958.0  IAD   3714.0         Y      0
# 2          3M     20710.0      MCN     3754.0  ATL   3682.0       NaN      0
# 3          3M     20710.0      MCN     3754.0  MCO   3878.0       NaN      0
# 4          3M     20710.0      MEI     4335.0  ATL   3682.0       NaN      0
# 5          3M     20710.0      MSL     5756.0  ATL   3682.0       NaN      0
# 6          3M     20710.0      PIB     5759.0  ATL   3682.0       NaN      0
# 7          3M     20710.0      TUP     5773.0  ATL   3682.0       NaN      0
# 8          3M     20710.0      TUP     5773.0  GLH   6130.0       NaN      0
# 9          9E      3976.0      AZO     4039.0  ATL   3682.0       NaN      0
# 10         AA        24.0      AZO     4039.0  ORD   3830.0         Y      0
# 11         DL      2009.0      AZO     4039.0  ATL   3682.0         Y      0
# 12         DL      2009.0      AZO     4039.0  DTW   3645.0       NaN      0
# 13         DL      2009.0      AZO     4039.0  MSP   3858.0         Y      0
# 14         US      5265.0      AZO     4039.0  ORD   3830.0         Y      0
# 15         9E      3976.0      CHA     3578.0  ATL   3682.0       NaN      0
# 16         AA        24.0      CHA     3578.0  CLT   3876.0       NaN      0
# 17         AA        24.0      CHA     3578.0  DCA   3520.0         Y      0
# 18         AA        24.0      CHA     3578.0  DFW   3670.0         Y      0
# 19         AA        24.0      CHA     3578.0  ORD   3830.0         Y      0
# 20         AF       137.0      CHA     3578.0  ATL   3682.0         Y      0
# 21         AZ       596.0      CHA     3578.0  ATL   3682.0         Y      0
# 22         DL      2009.0      CHA     3578.0  ATL   3682.0       NaN      0
# 23         DL      2009.0      CHA     3578.0  DTW   3645.0         Y      0
# 24         G4        35.0      CHA     3578.0  PIE   3617.0       NaN      0
# 25         G4        35.0      CHA     3578.0  SFB   4167.0       NaN      0
# 26         KL      3090.0      CHA     3578.0  ATL   3682.0         Y      0
# 27         US      5265.0      CHA     3578.0  CLT   3876.0         Y      0
# 28         US      5265.0      CHA     3578.0  DCA   3520.0         Y      0
# 29         US      5265.0      CHA     3578.0  DFW   3670.0       NaN      0
# ...       ...         ...      ...        ...  ...      ...       ...    ...
# 26232      Y4      5325.0      VER     1854.0  TIJ   1847.0       NaN      0
# 26233      4O     17885.0      VSA     1853.0  MEX   1824.0       NaN      0
# 26234      7M     16615.0      VSA     1853.0  MID   1819.0       NaN      0
# 26235      7M     16615.0      VSA     1853.0  VER   1854.0       NaN      0
# 26236      AM       321.0      VSA     1853.0  MEX   1824.0       NaN      0
# 26237      AM       321.0      VSA     1853.0  MID   1819.0       NaN      0
# 26238      AM       321.0      VSA     1853.0  PAZ   1830.0       NaN      0
# 26239      AM       321.0      VSA     1853.0  VER   1854.0       NaN      0
# 26240      DL      2009.0      VSA     1853.0  MEX   1824.0         Y      0
# 26241      UA      5209.0      VSA     1853.0  IAH   3550.0         Y      0
# 26242      VB     10646.0      VSA     1853.0  CUN   1852.0       NaN      0
# 26243      VB     10646.0      VSA     1853.0  GDL   1804.0       NaN      0
# 26244      VB     10646.0      VSA     1853.0  MTY   1825.0       NaN      0
# 26245      VW      1290.0      VSA     1853.0  PAZ   1830.0       NaN      0
# 26246      4O     17885.0      ZIH     1856.0  MEX   1824.0       NaN      0
# 26247      4O     17885.0      ZIH     1856.0  TLC   1850.0       NaN      0
# 26248      AA        24.0      ZIH     1856.0  PHX   3462.0       NaN      0
# 26249      AM       321.0      ZIH     1856.0  LAX   3484.0         Y      0
# 26250      AM       321.0      ZIH     1856.0  MEX   1824.0         Y      0
# 26251      AS       439.0      ZIH     1856.0  LAX   3484.0       NaN      0
# 26252      UA      5209.0      ZIH     1856.0  IAH   3550.0         Y      0
# 26253      US      5265.0      ZIH     1856.0  PHX   3462.0       NaN      0
# 26254      VW      1290.0      ZIH     1856.0  MEX   1824.0       NaN      0
# 26255      4O     17885.0      ZLO     1858.0  MEX   1824.0       NaN      0
# 26256      AM       321.0      ZLO     1858.0  LAX   3484.0         Y      0
# 26257      AM       321.0      ZLO     1858.0  MEX   1824.0         Y      0
# 26258      AS       439.0      ZLO     1858.0  LAX   3484.0       NaN      0
# 26259      UA      5209.0      ZLO     1858.0  IAH   3550.0         Y      0
# 26260      VW      1290.0      ZLO     1858.0  MEX   1824.0       NaN      0
# 26261      Y4      5325.0      ZLO     1858.0  TIJ   1847.0       NaN      0
#
#              equipment  id_source     ...      iata_dest icao_dest  \
# 0                  SF3     6958.0     ...            ATL      KATL
# 1                  SF3     6958.0     ...            IAD      KIAD
# 2                  SF3     3754.0     ...            ATL      KATL
# 3                  SF3     3754.0     ...            MCO      KMCO
# 4                  SF3     4335.0     ...            ATL      KATL
# 5                  SF3     5756.0     ...            ATL      KATL
# 6                 SF3      5759.0     ...            ATL      KATL
# 7                 SF3      5773.0     ...            ATL      KATL
# 8                  SF3     5773.0     ...            GLH      KGLH
# 9                  CRJ     4039.0     ...            ATL      KATL
# 10             ER4 ERD     4039.0     ...            ORD      KORD
# 11                 CRJ     4039.0     ...            ATL      KATL
# 12                 ERJ     4039.0     ...            DTW      KDTW
# 13                 CRJ     4039.0     ...            MSP      KMSP
# 14             ER4 ERD     4039.0     ...            ORD      KORD
# 15                 CRJ     3578.0     ...            ATL      KATL
# 16             CRJ DH8     3578.0     ...            CLT      KCLT
# 17                 CRJ     3578.0     ...            DCA      KDCA
# 18             ER4 ERD     3578.0     ...            DFW      KDFW
# 19             ER4 ERD     3578.0     ...            ORD      KORD
# 20                 CRJ     3578.0     ...            ATL      KATL
# 21             CRJ CR7     3578.0     ...            ATL      KATL
# 22                 M88     3578.0     ...            ATL      KATL
# 23                 CRJ     3578.0     ...            DTW      KDTW
# 24                 320     3578.0     ...            PIE      KPIE
# 25                 M80     3578.0     ...            SFB      KSFB
# 26                 CRJ     3578.0     ...            ATL      KATL
# 27             CRJ DH3     3578.0     ...            CLT      KCLT
# 28                 CRJ     3578.0     ...            DCA      KDCA
# 29                 ERD     3578.0     ...            DFW      KDFW
# ...                ...        ...     ...            ...       ...
# 26232              320     1854.0     ...            TIJ      MMTJ
# 26233              320     1853.0     ...            MEX      MMMX
# 26234              D28     1853.0     ...            MID      MMMD
# 26235              D28     1853.0     ...            VER      MMVR
# 26236  737 EMJ ERJ E70     1853.0     ...            MEX      MMMX
# 26237              AT7     1853.0     ...            MID      MMMD
# 26238              ATR     1853.0     ...            PAZ      MMPA
# 26239              AT7     1853.0     ...            VER      MMVR
# 26240              737     1853.0     ...            MEX      MMMX
# 26241              CR7     1853.0     ...            IAH      KIAH
# 26242              733     1853.0     ...            CUN      MMUN
# 26243              733     1853.0     ...            GDL      MMGL
# 26244              733     1853.0     ...            MTY      MMMY
# 26245              ATR     1853.0     ...            PAZ      MMPA
# 26246              320     1856.0     ...            MEX      MMMX
# 26247              320     1856.0     ...            TLC      MMTO
# 26248              320     1856.0     ...            PHX      KPHX
# 26249              739     1856.0     ...            LAX      KLAX
# 26250          ERJ EMJ     1856.0     ...            MEX      MMMX
# 26251              739     1856.0     ...            LAX      KLAX
# 26252              ERJ     1856.0     ...            IAH      KIAH
# 26253              320     1856.0     ...            PHX      KPHX
# 26254              ATR     1856.0     ...            MEX      MMMX
# 26255              SU9     1858.0     ...            MEX      MMMX
# 26256              73H     1858.0     ...            LAX      KLAX
# 26257          E75 ERJ     1858.0     ...            MEX      MMMX
# 26258              73H     1858.0     ...            LAX      KLAX
# 26259              ERJ     1858.0     ...            IAH      KIAH
# 26260              ATR     1858.0     ...            MEX      MMMX
# 26261              319     1858.0     ...            TIJ      MMTJ
#
#       latitude_dest longitude_dest altitude_dest  timezone_dest  dst_dest  \
# 0         33.636700     -84.428101        1026.0           -5.0         A
# 1         38.944500     -77.455803         312.0           -5.0         A
# 2         33.636700     -84.428101        1026.0           -5.0         A
# 3         28.429399     -81.308998          96.0           -5.0         A
# 4         33.636700     -84.428101        1026.0           -5.0         A
# 5         33.636700     -84.428101        1026.0           -5.0         A
# 6         33.636700     -84.428101        1026.0           -5.0         A
# 7         33.636700     -84.428101        1026.0           -5.0         A
# 8         33.482899     -90.985603         131.0           -6.0         A
# 9         33.636700     -84.428101        1026.0           -5.0         A
# 10        41.978600     -87.904800         672.0           -6.0         A
# 11        33.636700     -84.428101        1026.0           -5.0         A
# 12        42.212399     -83.353401         645.0           -5.0         A
# 13        44.882000     -93.221802         841.0           -6.0         A
# 14        41.978600     -87.904800         672.0           -6.0         A
# 15        33.636700     -84.428101        1026.0           -5.0         A
# 16        35.214001     -80.943100         748.0           -5.0         A
# 17        38.852100     -77.037697          15.0           -5.0         A
# 18        32.896801     -97.038002         607.0           -6.0         A
# 19        41.978600     -87.904800         672.0           -6.0         A
# 20        33.636700     -84.428101        1026.0           -5.0         A
# 21        33.636700     -84.428101        1026.0           -5.0         A
# 22        33.636700     -84.428101        1026.0           -5.0         A
# 23        42.212399     -83.353401         645.0           -5.0         A
# 24        27.910200     -82.687401          11.0           -5.0         A
# 25        28.777599     -81.237503          55.0           -5.0         A
# 26        33.636700     -84.428101        1026.0           -5.0         A
# 27        35.214001     -80.943100         748.0           -5.0         A
# 28        38.852100     -77.037697          15.0           -5.0         A
# 29        32.896801     -97.038002         607.0           -6.0         A
# ...             ...            ...           ...            ...       ...
# 26232     32.541100    -116.970001         489.0           -8.0         S
# 26233     19.436300     -99.072098        7316.0           -6.0         S
# 26234     20.937000     -89.657700          38.0           -6.0         S
# 26235     19.145901     -96.187302          90.0           -6.0         S
# 26236     19.436300     -99.072098        7316.0           -6.0         S
# 26237     20.937000     -89.657700          38.0           -6.0         S
# 26238     20.602699     -97.460800         497.0           -6.0         S
# 26239     19.145901     -96.187302          90.0           -6.0         S
# 26240     19.436300     -99.072098        7316.0           -6.0         S
# 26241     29.984400     -95.341400          97.0           -6.0         A
# 26242     21.036501     -86.877098          22.0           -5.0         S
# 26243     20.521799    -103.310997        5016.0           -6.0         S
# 26244     25.778500    -100.107002        1278.0           -6.0         S
# 26245     20.602699     -97.460800         497.0           -6.0         S
# 26246     19.436300     -99.072098        7316.0           -6.0         S
# 26247     19.337099     -99.566002        8466.0           -6.0         S
# 26248     33.434299    -112.012001        1135.0           -7.0         N
# 26249     33.942501    -118.407997         125.0           -8.0         A
# 26250     19.436300     -99.072098        7316.0           -6.0         S
# 26251     33.942501    -118.407997         125.0           -8.0         A
# 26252     29.984400     -95.341400          97.0           -6.0         A
# 26253     33.434299    -112.012001        1135.0           -7.0         N
# 26254     19.436300     -99.072098        7316.0           -6.0         S
# 26255     19.436300     -99.072098        7316.0           -6.0         S
# 26256     33.942501    -118.407997         125.0           -8.0         A
# 26257     19.436300     -99.072098        7316.0           -6.0         S
# 26258     33.942501    -118.407997         125.0           -8.0         A
# 26259     29.984400     -95.341400          97.0           -6.0         A
# 26260     19.436300     -99.072098        7316.0           -6.0         S
# 26261     32.541100    -116.970001         489.0           -8.0         S
#
#                    tz_dest  type_dest       source
# 0         America/New_York    airport  OurAirports
# 1         America/New_York    airport  OurAirports
# 2         America/New_York    airport  OurAirports
# 3         America/New_York    airport  OurAirports
# 4         America/New_York    airport  OurAirports
# 5         America/New_York    airport  OurAirports
# 6         America/New_York    airport  OurAirports
# 7         America/New_York    airport  OurAirports
# 8          America/Chicago    airport  OurAirports
# 9         America/New_York    airport  OurAirports
# 10         America/Chicago    airport  OurAirports
# 11        America/New_York    airport  OurAirports
# 12        America/New_York    airport  OurAirports
# 13         America/Chicago    airport  OurAirports
# 14         America/Chicago    airport  OurAirports
# 15        America/New_York    airport  OurAirports
# 16        America/New_York    airport  OurAirports
# 17        America/New_York    airport  OurAirports
# 18         America/Chicago    airport  OurAirports
# 19         America/Chicago    airport  OurAirports
# 20        America/New_York    airport  OurAirports
# 21        America/New_York    airport  OurAirports
# 22        America/New_York    airport  OurAirports
# 23        America/New_York    airport  OurAirports
# 24        America/New_York    airport  OurAirports
# 25        America/New_York    airport  OurAirports
# 26        America/New_York    airport  OurAirports
# 27        America/New_York    airport  OurAirports
# 28        America/New_York    airport  OurAirports
# 29         America/Chicago    airport  OurAirports
# ...                    ...        ...          ...
# 26232      America/Tijuana    airport  OurAirports
# 26233  America/Mexico_City    airport  OurAirports
# 26234  America/Mexico_City    airport  OurAirports
# 26235  America/Mexico_City    airport  OurAirports
# 26236  America/Mexico_City    airport  OurAirports
# 26237  America/Mexico_City    airport  OurAirports
# 26238  America/Mexico_City    airport  OurAirports
# 26239  America/Mexico_City    airport  OurAirports
# 26240  America/Mexico_City    airport  OurAirports
# 26241      America/Chicago    airport  OurAirports
# 26242       America/Cancun    airport  OurAirports
# 26243  America/Mexico_City    airport  OurAirports
# 26244  America/Mexico_City    airport  OurAirports
# 26245  America/Mexico_City    airport  OurAirports
# 26246  America/Mexico_City    airport  OurAirports
# 26247  America/Mexico_City    airport  OurAirports
# 26248      America/Phoenix    airport  OurAirports
# 26249  America/Los_Angeles    airport  OurAirports
# 26250  America/Mexico_City    airport  OurAirports
# 26251  America/Los_Angeles    airport  OurAirports
# 26252      America/Chicago    airport  OurAirports
# 26253      America/Phoenix    airport  OurAirports
# 26254  America/Mexico_City    airport  OurAirports
# 26255  America/Mexico_City    airport  OurAirports
# 26256  America/Los_Angeles    airport  OurAirports
# 26257  America/Mexico_City    airport  OurAirports
# 26258  America/Los_Angeles    airport  OurAirports
# 26259      America/Chicago    airport  OurAirports
# 26260  America/Mexico_City    airport  OurAirports
# 26261      America/Tijuana    airport  OurAirports
#
# [26262 rows x 37 columns]

# %%
# join the destination airports.  Here we need to use the suffixes option, because 
# the column names overlap, and we want to distinguish between source and dest
oneStopLex_routes = pd.merge(oneStopLex_routes, airports, 
                      left_on='dest_id', 
                      right_on='id', 
                      how='left', 
                      suffixes=['_source','_dest'])
oneStopLex_routes
# Out:
#      airline  airline_id source_x  source_id dest  dest_id codeshare  stops  \
# 0         3M     20710.0      ATL     3682.0  LWB   6958.0       NaN      0
# 1         3M     20710.0      ATL     3682.0  MCN   3754.0       NaN      0
# 2         3M     20710.0      ATL     3682.0  MEI   4335.0       NaN      0
# 3         3M     20710.0      ATL     3682.0  MSL   5756.0       NaN      0
# 4         3M     20710.0      ATL     3682.0  PIB   5759.0       NaN      0
# 5         3M     20710.0      ATL     3682.0  TUP   5773.0       NaN      0
# 6         9E      3976.0      ATL     3682.0  AZO   4039.0       NaN      0
# 7         9E      3976.0      ATL     3682.0  CHA   3578.0       NaN      0
# 8         9E      3976.0      ATL     3682.0  CID   4043.0       NaN      0
# 9         9E      3976.0      ATL     3682.0  CRW   4285.0       NaN      0
# 10        9E      3976.0      ATL     3682.0  CVG   3488.0       NaN      0
# 11        9E      3976.0      ATL     3682.0  EVV   4018.0       NaN      0
# 12        9E      3976.0      ATL     3682.0  FWA   4041.0       NaN      0
# 13        9E      3976.0      ATL     3682.0  GSO   4008.0       NaN      0
# 14        9E      3976.0      ATL     3682.0  GSP   4034.0       NaN      0
# 15        9E      3976.0      ATL     3682.0  LAN   3544.0       NaN      0
# 16        9E      3976.0      ATL     3682.0  LEX   4017.0       NaN      0
# 17        9E      3976.0      ATL     3682.0  MBS   4128.0       NaN      0
# 18        9E      3976.0      ATL     3682.0  MSP   3858.0       NaN      0
# 19        9E      3976.0      ATL     3682.0  ROA   4016.0       NaN      0
# 20        9E      3976.0      ATL     3682.0  SYR   3745.0       NaN      0
# 21        9E      3976.0      ATL     3682.0  TYS   3676.0       NaN      0
# 22        9E      3976.0      ATL     3682.0  XNA   4356.0       NaN      0
# 23        AA        24.0      ATL     3682.0  CLT   3876.0         Y      0
# 24        AA        24.0      ATL     3682.0  DFW   3670.0       NaN      0
# 25        AA        24.0      ATL     3682.0  LHR    507.0         Y      0
# 26        AA        24.0      ATL     3682.0  MIA   3576.0       NaN      0
# 27        AA        24.0      ATL     3682.0  ORD   3830.0         Y      0
# 28        AA        24.0      ATL     3682.0  PHL   3752.0         Y      0
# 29        AA        24.0      ATL     3682.0  PHX   3462.0         Y      0
# ...      ...         ...      ...        ...  ...      ...       ...    ...
# 3528      UA      5209.0      IAH     3550.0  TUL   3855.0         Y      0
# 3529      UA      5209.0      IAH     3550.0  TUS   3636.0         Y      0
# 3530      UA      5209.0      IAH     3550.0  TYR   3848.0         Y      0
# 3531      UA      5209.0      IAH     3550.0  TYS   3676.0         Y      0
# 3532      UA      5209.0      IAH     3550.0  UIO   2688.0       NaN      0
# 3533      UA      5209.0      IAH     3550.0  VER   1854.0         Y      0
# 3534      UA      5209.0      IAH     3550.0  VPS   3873.0         Y      0
# 3535      UA      5209.0      IAH     3550.0  VSA   1853.0         Y      0
# 3536      UA      5209.0      IAH     3550.0  XNA   4356.0         Y      0
# 3537      UA      5209.0      IAH     3550.0  YEG     49.0       NaN      0
# 3538      UA      5209.0      IAH     3550.0  YUL    146.0         Y      0
# 3539      UA      5209.0      IAH     3550.0  YVR    156.0       NaN      0
# 3540      UA      5209.0      IAH     3550.0  YYC    178.0       NaN      0
# 3541      UA      5209.0      IAH     3550.0  YYZ    193.0         Y      0
# 3542      UA      5209.0      IAH     3550.0  ZIH   1856.0         Y      0
# 3543      UA      5209.0      IAH     3550.0  ZLO   1858.0         Y      0
# 3544      UN      5067.0      IAH     3550.0  DME   4029.0         Y      0
# 3545      US      5265.0      IAH     3550.0  CLT   3876.0       NaN      0
# 3546      US      5265.0      IAH     3550.0  DFW   3670.0       NaN      0
# 3547      US      5265.0      IAH     3550.0  DOH  11051.0       NaN      0
# 3548      US      5265.0      IAH     3550.0  IST   1701.0       NaN      0
# 3549      US      5265.0      IAH     3550.0  LAX   3484.0       NaN      0
# 3550      US      5265.0      IAH     3550.0  MIA   3576.0       NaN      0
# 3551      US      5265.0      IAH     3550.0  ORD   3830.0       NaN      0
# 3552      US      5265.0      IAH     3550.0  PHL   3752.0       NaN      0
# 3553      US      5265.0      IAH     3550.0  PHX   3462.0       NaN      0
# 3554      US      5265.0      IAH     3550.0  SAL   1892.0       NaN      0
# 3555      VA      5360.0      IAH     3550.0  ATL   3682.0         Y      0
# 3556      VB     10646.0      IAH     3550.0  MTY   1825.0       NaN      0
# 3557      VS      5347.0      IAH     3550.0  ATL   3682.0         Y      0
#
#                 equipment  id_source     ...      iata_dest icao_dest  \
# 0                     SF3       3682     ...            LWB      KLWB
# 1                     SF3       3682     ...            MCN      KMCN
# 2                     SF3       3682     ...            MEI      KMEI
# 3                     SF3       3682     ...            MSL      KMSL
# 4                     SF3       3682     ...            PIB      KPIB
# 5                     SF3       3682     ...            TUP      KTUP
# 6                     CRJ       3682     ...            AZO      KAZO
# 7                     CRJ       3682     ...            CHA      KCHA
# 8                     CRJ       3682     ...            CID      KCID
# 9                     CRJ       3682     ...            CRW      KCRW
# 10                   CR9        3682     ...            CVG      KCVG
# 11                    CRJ       3682     ...            EVV      KEVV
# 12                    CRJ       3682     ...            FWA      KFWA
# 13                    CR9       3682     ...            GSO      KGSO
# 14                    CRJ       3682     ...            GSP      KGSP
# 15                    CRJ       3682     ...            LAN      KLAN
# 16                    CRJ       3682     ...            LEX      KLEX
# 17                    CRJ       3682     ...            MBS      KMBS
# 18                    NaN       3682     ...            MSP      KMSP
# 19                    CRJ       3682     ...            ROA      KROA
# 20                    CR9       3682     ...            SYR      KSYR
# 21                CRJ CR9       3682     ...            TYS      KTYS
# 22                    CRJ       3682     ...            XNA      KXNA
# 23        319 320 CR9 321       3682     ...            CLT      KCLT
# 24            M80 319 M83       3682     ...            DFW      KDFW
# 25                    777       3682     ...            LHR      EGLL
# 26                    738       3682     ...            MIA      KMIA
# 27                CR7 E75       3682     ...            ORD      KORD
# 28    E75 E90 319 CRJ E70       3682     ...            PHL      KPHL
# 29                320 321       3682     ...            PHX      KPHX
# ...                   ...        ...     ...            ...       ...
# 3528          CRJ ERJ CR7       3550     ...            TUL      KTUL
# 3529              ERJ CR7       3550     ...            TUS      KTUS
# 3530                  ERJ       3550     ...            TYR      KTYR
# 3531                  ERJ       3550     ...            TYS      KTYS
# 3532              73G 738       3550     ...            UIO      SEQM
# 3533                  ERJ       3550     ...            VER      MMVR
# 3534                  ERJ       3550     ...            VPS      KVPS
# 3535                  CR7       3550     ...            VSA      MMVA
# 3536              CRJ ERJ       3550     ...            XNA      KXNA
# 3537      738 320 73G 319       3550     ...            YEG      CYEG
# 3538                  E70       3550     ...            YUL      CYUL
# 3539          320 319 739       3550     ...            YVR      CYVR
# 3540          738 320 739       3550     ...            YYC      CYYC
# 3541          CRA ERJ CR7       3550     ...            YYZ      CYYZ
# 3542                  ERJ       3550     ...            ZIH      MMZH
# 3543                  ERJ       3550     ...            ZLO      MMZO
# 3544                  77W       3550     ...            DME      UUDD
# 3545      321 734 319 320       3550     ...            CLT      KCLT
# 3546              M80 M83       3550     ...            DFW      KDFW
# 3547                  77L       3550     ...            NaN       NaN
# 3548                  77W       3550     ...            IST      LTBA
# 3549                  CR7       3550     ...            LAX      KLAX
# 3550                  738       3550     ...            MIA      KMIA
# 3551                  CR7       3550     ...            ORD      KORD
# 3552                  E90       3550     ...            PHL      KPHL
# 3553              319 320       3550     ...            PHX      KPHX
# 3554                  E90       3550     ...            SAL      MSLP
# 3555          M88 717 319       3550     ...            ATL      KATL
# 3556                  733       3550     ...            MTY      MMMY
# 3557          M88 717 319       3550     ...            ATL      KATL
#
#      latitude_dest longitude_dest altitude_dest  timezone_dest  dst_dest  \
# 0        37.858299     -80.399498        2302.0           -5.0         U
# 1        32.692799     -83.649200         354.0           -5.0         A
# 2        32.332600     -88.751900         297.0           -6.0         A
# 3        34.745300     -87.610199         551.0           -6.0         A
# 4        31.467100     -89.337097         298.0           -6.0         A
# 5        34.268101     -88.769897         346.0           -6.0         A
# 6        42.234901     -85.552101         874.0           -5.0         A
# 7        35.035301     -85.203796         683.0           -5.0         A
# 8        41.884701     -91.710800         869.0           -6.0         A
# 9        38.373100     -81.593201         981.0           -5.0         A
# 10       39.048801     -84.667801         896.0           -5.0         A
# 11       38.036999     -87.532402         418.0           -6.0         A
# 12       40.978500     -85.195099         814.0           -5.0         A
# 13       36.097801     -79.937302         925.0           -5.0         A
# 14       34.895699     -82.218903         964.0           -5.0         A
# 15       42.778702     -84.587402         861.0           -5.0         A
# 16       38.036499     -84.605904         979.0           -5.0         A
# 17       43.532902     -84.079597         668.0           -5.0         A
# 18       44.882000     -93.221802         841.0           -6.0         A
# 19       37.325500     -79.975403        1175.0           -5.0         A
# 20       43.111198     -76.106300         421.0           -5.0         A
# 21       35.811001     -83.994003         981.0           -5.0         A
# 22       36.281898     -94.306801        1287.0           -6.0         A
# 23       35.214001     -80.943100         748.0           -5.0         A
# 24       32.896801     -97.038002         607.0           -6.0         A
# 25       51.470600      -0.461941          83.0            0.0         E
# 26       25.793200     -80.290604           8.0           -5.0         A
# 27       41.978600     -87.904800         672.0           -6.0         A
# 28       39.871899     -75.241096          36.0           -5.0         A
# 29       33.434299    -112.012001        1135.0           -7.0         N
# ...            ...            ...           ...            ...       ...
# 3528     36.198399     -95.888100         677.0           -6.0         A
# 3529     32.116100    -110.941002        2643.0           -7.0         N
# 3530     32.354099     -95.402397         544.0           -6.0         A
# 3531     35.811001     -83.994003         981.0           -5.0         A
# 3532     -0.129167     -78.357500        7841.0           -5.0         U
# 3533     19.145901     -96.187302          90.0           -6.0         S
# 3534     30.483200     -86.525398          87.0           -6.0         A
# 3535     17.997000     -92.817398          46.0           -6.0         S
# 3536     36.281898     -94.306801        1287.0           -6.0         A
# 3537     53.309700    -113.580002        2373.0           -7.0         A
# 3538     45.470600     -73.740799         118.0           -5.0         A
# 3539     49.193901    -123.183998          14.0           -8.0         A
# 3540     51.113899    -114.019997        3557.0           -7.0         A
# 3541     43.677200     -79.630600         569.0           -5.0         A
# 3542     17.601601    -101.460999          26.0           -6.0         S
# 3543     19.144800    -104.558998          30.0           -6.0         S
# 3544     55.408798      37.906300         588.0            3.0         N
# 3545     35.214001     -80.943100         748.0           -5.0         A
# 3546     32.896801     -97.038002         607.0           -6.0         A
# 3547           NaN            NaN           NaN            NaN       NaN
# 3548     40.976898      28.814600         163.0            3.0         E
# 3549     33.942501    -118.407997         125.0           -8.0         A
# 3550     25.793200     -80.290604           8.0           -5.0         A
# 3551     41.978600     -87.904800         672.0           -6.0         A
# 3552     39.871899     -75.241096          36.0           -5.0         A
# 3553     33.434299    -112.012001        1135.0           -7.0         N
# 3554     13.440900     -89.055702         101.0           -6.0         U
# 3555     33.636700     -84.428101        1026.0           -5.0         A
# 3556     25.778500    -100.107002        1278.0           -6.0         S
# 3557     33.636700     -84.428101        1026.0           -5.0         A
#
#                   tz_dest  type_dest       source
# 0        America/New_York    airport  OurAirports
# 1        America/New_York    airport  OurAirports
# 2         America/Chicago    airport  OurAirports
# 3         America/Chicago    airport  OurAirports
# 4         America/Chicago    airport  OurAirports
# 5         America/Chicago    airport  OurAirports
# 6        America/New_York    airport  OurAirports
# 7        America/New_York    airport  OurAirports
# 8         America/Chicago    airport  OurAirports
# 9        America/New_York    airport  OurAirports
# 10       America/New_York    airport  OurAirports
# 11        America/Chicago    airport  OurAirports
# 12       America/New_York    airport  OurAirports
# 13       America/New_York    airport  OurAirports
# 14       America/New_York    airport  OurAirports
# 15       America/New_York    airport  OurAirports
# 16       America/New_York    airport  OurAirports
# 17       America/New_York    airport  OurAirports
# 18        America/Chicago    airport  OurAirports
# 19       America/New_York    airport  OurAirports
# 20       America/New_York    airport  OurAirports
# 21       America/New_York    airport  OurAirports
# 22        America/Chicago    airport  OurAirports
# 23       America/New_York    airport  OurAirports
# 24        America/Chicago    airport  OurAirports
# 25          Europe/London    airport  OurAirports
# 26       America/New_York    airport  OurAirports
# 27        America/Chicago    airport  OurAirports
# 28       America/New_York    airport  OurAirports
# 29        America/Phoenix    airport  OurAirports
# ...                   ...        ...          ...
# 3528      America/Chicago    airport  OurAirports
# 3529      America/Phoenix    airport  OurAirports
# 3530      America/Chicago    airport  OurAirports
# 3531     America/New_York    airport  OurAirports
# 3532    America/Guayaquil    airport  OurAirports
# 3533  America/Mexico_City    airport  OurAirports
# 3534      America/Chicago    airport  OurAirports
# 3535  America/Mexico_City    airport  OurAirports
# 3536      America/Chicago    airport  OurAirports
# 3537     America/Edmonton    airport  OurAirports
# 3538      America/Toronto    airport  OurAirports
# 3539    America/Vancouver    airport  OurAirports
# 3540     America/Edmonton    airport  OurAirports
# 3541      America/Toronto    airport  OurAirports
# 3542  America/Mexico_City    airport  OurAirports
# 3543  America/Mexico_City    airport  OurAirports
# 3544        Europe/Moscow    airport  OurAirports
# 3545     America/New_York    airport  OurAirports
# 3546      America/Chicago    airport  OurAirports
# 3547                  NaN        NaN          NaN
# 3548      Europe/Istanbul    airport  OurAirports
# 3549  America/Los_Angeles    airport  OurAirports
# 3550     America/New_York    airport  OurAirports
# 3551      America/Chicago    airport  OurAirports
# 3552     America/New_York    airport  OurAirports
# 3553      America/Phoenix    airport  OurAirports
# 3554  America/El_Salvador    airport  OurAirports
# 3555     America/New_York    airport  OurAirports
# 3556  America/Mexico_City    airport  OurAirports
# 3557     America/New_York    airport  OurAirports
#
# [3558 rows x 37 columns]

# %%
twoStopLex_routes.count()
# Out:
# airline             26262
# airline_id          26207
# source_x            26262
# source_id           26262
# dest                26262
# dest_id             26232
# codeshare            8336
# stops               26262
# equipment           26248
# id_source           26073
# name_source         26073
# city_source         26073
# country_source      26073
# iata_source         26073
# icao_source         26073
# latitude_source     26073
# longitude_source    26073
# altitude_source     26073
# timezone_source     26073
# dst_source          26073
# tz_source           26073
# type_source         26073
# source_y            26073
# id_dest             26097
# name_dest           26097
# city_dest           26097
# country_dest        26097
# iata_dest           26097
# icao_dest           26097
# latitude_dest       26097
# longitude_dest      26097
# altitude_dest       26097
# timezone_dest       26097
# dst_dest            26097
# tz_dest             26086
# type_dest           26097
# source              26097
# dtype: int64

# %%
# here is what our data looks like
lex_routes.count()
# Out:
# airline             20
# airline_id          20
# source_x            20
# source_id           20
# dest                20
# dest_id             20
# codeshare           11
# stops               20
# equipment           20
# id_source           20
# name_source         20
# city_source         20
# country_source      20
# iata_source         20
# icao_source         20
# latitude_source     20
# longitude_source    20
# altitude_source     20
# timezone_source     20
# dst_source          20
# tz_source           20
# type_source         20
# source_y            20
# id_dest             20
# name_dest           20
# city_dest           20
# country_dest        20
# iata_dest           20
# icao_dest           20
# latitude_dest       20
# longitude_dest      20
# altitude_dest       20
# timezone_dest       20
# dst_dest            20
# tz_dest             20
# type_dest           20
# source_source       20
# id                  20
# name                20
# city                20
# country             20
# iata                20
# icao                20
# latitude            20
# longitude           20
# altitude            20
# timezone            20
# dst                 20
# tz                  20
# type                20
# source_dest         20
# dtype: int64

# %%
# It looks like source has some duplicate names.  Drop the values from the airports
# file ane keep the one from the routes file
oneStopLex_routes = oneStopLex_routes.drop(['source_y','source'], axis=1)
oneStopLex_routes = oneStopLex_routes.rename(columns={'source_x': 'source'})

# %%
# It looks like source has some duplicate names.  Drop the values from the airports
# file ane keep the one from the routes file
twoStopLex_routes = twoStopLex_routes.drop(['source_y','source'], axis=1)
twoStopLex_routes = twoStopLex_routes.rename(columns={'source_x': 'source'})

# %%
# Let's keep only one route between each airport pair
# so we don't have a bunch of lines on top of each other
# The subset option tells it to consider just those columns when determining
# what is a duplicate. 
twoStopLex_routes = twoStopLex_routes.drop_duplicates(subset=['source', 'dest'])
twoStopLex_routes.count()
# Out:
# airline             12759
# airline_id          12720
# source              12759
# source_id           12759
# dest                12759
# dest_id             12739
# codeshare            3937
# stops               12759
# equipment           12753
# id_source           12643
# name_source         12643
# city_source         12643
# country_source      12643
# iata_source         12643
# icao_source         12643
# latitude_source     12643
# longitude_source    12643
# altitude_source     12643
# timezone_source     12643
# dst_source          12643
# tz_source           12643
# type_source         12643
# id_dest             12658
# name_dest           12658
# city_dest           12658
# country_dest        12658
# iata_dest           12658
# icao_dest           12658
# latitude_dest       12658
# longitude_dest      12658
# altitude_dest       12658
# timezone_dest       12658
# dst_dest            12658
# tz_dest             12651
# type_dest           12658
# dtype: int64

# %%
# Let's keep only one route between each airport pair
# so we don't have a bunch of lines on top of each other
# The subset option tells it to consider just those columns when determining
# what is a duplicate. 
oneStopLex_routes = oneStopLex_routes.drop_duplicates(subset=['source', 'dest'])
oneStopLex_routes.count()
# Out:
# airline             399
# airline_id          398
# source              399
# source_id           399
# dest                399
# dest_id             399
# codeshare           266
# stops               399
# equipment           398
# id_source           399
# name_source         399
# city_source         399
# country_source      399
# iata_source         399
# icao_source         399
# latitude_source     399
# longitude_source    399
# altitude_source     399
# timezone_source     399
# dst_source          399
# tz_source           399
# type_source         399
# id_dest             398
# name_dest           398
# city_dest           398
# country_dest        398
# iata_dest           398
# icao_dest           398
# latitude_dest       398
# longitude_dest      398
# altitude_dest       398
# timezone_dest       398
# dst_dest            398
# tz_dest             398
# type_dest           398
# dtype: int64

# %%
# Let's keep only one route between each airport pair
# so we don't have a bunch of lines on top of each other
# The subset option tells it to consider just those columns when determining
# what is a duplicate. 

oneStopLex_routes = oneStopLex_routes.drop_duplicates(subset=['source', 'dest'])
oneStopLex_routes
# Out:
#      airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 0         3M     20710.0    ATL     3682.0  LWB   6958.0       NaN      0
# 1         3M     20710.0    ATL     3682.0  MCN   3754.0       NaN      0
# 2         3M     20710.0    ATL     3682.0  MEI   4335.0       NaN      0
# 3         3M     20710.0    ATL     3682.0  MSL   5756.0       NaN      0
# 4         3M     20710.0    ATL     3682.0  PIB   5759.0       NaN      0
# 5         3M     20710.0    ATL     3682.0  TUP   5773.0       NaN      0
# 6         9E      3976.0    ATL     3682.0  AZO   4039.0       NaN      0
# 7         9E      3976.0    ATL     3682.0  CHA   3578.0       NaN      0
# 8         9E      3976.0    ATL     3682.0  CID   4043.0       NaN      0
# 9         9E      3976.0    ATL     3682.0  CRW   4285.0       NaN      0
# 10        9E      3976.0    ATL     3682.0  CVG   3488.0       NaN      0
# 11        9E      3976.0    ATL     3682.0  EVV   4018.0       NaN      0
# 12        9E      3976.0    ATL     3682.0  FWA   4041.0       NaN      0
# 13        9E      3976.0    ATL     3682.0  GSO   4008.0       NaN      0
# 14        9E      3976.0    ATL     3682.0  GSP   4034.0       NaN      0
# 15        9E      3976.0    ATL     3682.0  LAN   3544.0       NaN      0
# 16        9E      3976.0    ATL     3682.0  LEX   4017.0       NaN      0
# 17        9E      3976.0    ATL     3682.0  MBS   4128.0       NaN      0
# 18        9E      3976.0    ATL     3682.0  MSP   3858.0       NaN      0
# 19        9E      3976.0    ATL     3682.0  ROA   4016.0       NaN      0
# 20        9E      3976.0    ATL     3682.0  SYR   3745.0       NaN      0
# 21        9E      3976.0    ATL     3682.0  TYS   3676.0       NaN      0
# 22        9E      3976.0    ATL     3682.0  XNA   4356.0       NaN      0
# 23        AA        24.0    ATL     3682.0  CLT   3876.0         Y      0
# 24        AA        24.0    ATL     3682.0  DFW   3670.0       NaN      0
# 25        AA        24.0    ATL     3682.0  LHR    507.0         Y      0
# 26        AA        24.0    ATL     3682.0  MIA   3576.0       NaN      0
# 27        AA        24.0    ATL     3682.0  ORD   3830.0         Y      0
# 28        AA        24.0    ATL     3682.0  PHL   3752.0         Y      0
# 29        AA        24.0    ATL     3682.0  PHX   3462.0         Y      0
# ...      ...         ...    ...        ...  ...      ...       ...    ...
# 3132      NK      4687.0    FLL     3533.0  LBE   5747.0       NaN      0
# 3150      NK      4687.0    FLL     3533.0  STI   1764.0       NaN      0
# 3153      NK      4687.0    FLL     3533.0  TLC   1850.0       NaN      0
# 3155      NK      4687.0    FLL     3533.0  ZSA   1956.0       NaN      0
# 3228      G4        35.0    PGD     7056.0  RFD   4028.0       NaN      0
# 3234      G4        35.0    PGD     7056.0  YNG   3881.0       NaN      0
# 3250      G4        35.0    PIE     3617.0  LCK   3674.0       NaN      0
# 3266      FI      2835.0    SFB     4167.0  KEF     16.0       NaN      0
# 3273      G4        35.0    SFB     4167.0  BLV   3790.0       NaN      0
# 3278      G4        35.0    SFB     4167.0  CKB   5730.0       NaN      0
# 3289      G4        35.0    SFB     4167.0  HGR   6739.0       NaN      0
# 3299      G4        35.0    SFB     4167.0  OWB   5758.0       NaN      0
# 3302      G4        35.0    SFB     4167.0  PSM   5763.0       NaN      0
# 3369      LW      3865.0    IAH     3550.0  VCT   5775.0         Y      0
# 3379      SQ      4435.0    IAH     3550.0  DME   4029.0       NaN      0
# 3383      UA      5209.0    IAH     3550.0  ACA   1783.0         Y      0
# 3391      UA      5209.0    IAH     3550.0  BFL   3558.0         Y      0
# 3408      UA      5209.0    IAH     3550.0  CME   1789.0         Y      0
# 3421      UA      5209.0    IAH     3550.0  DGO   1801.0         Y      0
# 3440      UA      5209.0    IAH     3550.0  HOB   3749.0         Y      0
# 3441      UA      5209.0    IAH     3550.0  HRL   3560.0         Y      0
# 3443      UA      5209.0    IAH     3550.0  HUX   1786.0         Y      0
# 3471      UA      5209.0    IAH     3550.0  MID   1819.0       NaN      0
# 3482      UA      5209.0    IAH     3550.0  OAX   1829.0         Y      0
# 3520      UA      5209.0    IAH     3550.0  SLW   1810.0         Y      0
# 3524      UA      5209.0    IAH     3550.0  TAM   1848.0         Y      0
# 3533      UA      5209.0    IAH     3550.0  VER   1854.0         Y      0
# 3535      UA      5209.0    IAH     3550.0  VSA   1853.0         Y      0
# 3542      UA      5209.0    IAH     3550.0  ZIH   1856.0         Y      0
# 3543      UA      5209.0    IAH     3550.0  ZLO   1858.0         Y      0
#
#                 equipment  id_source    ...           country_dest iata_dest  \
# 0                     SF3       3682    ...          United States       LWB
# 1                     SF3       3682    ...          United States       MCN
# 2                     SF3       3682    ...          United States       MEI
# 3                     SF3       3682    ...          United States       MSL
# 4                     SF3       3682    ...          United States       PIB
# 5                     SF3       3682    ...          United States       TUP
# 6                     CRJ       3682    ...          United States       AZO
# 7                     CRJ       3682    ...          United States       CHA
# 8                     CRJ       3682    ...          United States       CID
# 9                     CRJ       3682    ...          United States       CRW
# 10                   CR9        3682    ...          United States       CVG
# 11                    CRJ       3682    ...          United States       EVV
# 12                    CRJ       3682    ...          United States       FWA
# 13                    CR9       3682    ...          United States       GSO
# 14                    CRJ       3682    ...          United States       GSP
# 15                    CRJ       3682    ...          United States       LAN
# 16                    CRJ       3682    ...          United States       LEX
# 17                    CRJ       3682    ...          United States       MBS
# 18                    NaN       3682    ...          United States       MSP
# 19                    CRJ       3682    ...          United States       ROA
# 20                    CR9       3682    ...          United States       SYR
# 21                CRJ CR9       3682    ...          United States       TYS
# 22                    CRJ       3682    ...          United States       XNA
# 23        319 320 CR9 321       3682    ...          United States       CLT
# 24            M80 319 M83       3682    ...          United States       DFW
# 25                    777       3682    ...         United Kingdom       LHR
# 26                    738       3682    ...          United States       MIA
# 27                CR7 E75       3682    ...          United States       ORD
# 28    E75 E90 319 CRJ E70       3682    ...          United States       PHL
# 29                320 321       3682    ...          United States       PHX
# ...                   ...        ...    ...                    ...       ...
# 3132                  319       3533    ...          United States       LBE
# 3150                  319       3533    ...     Dominican Republic       STI
# 3153                  319       3533    ...                 Mexico       TLC
# 3155                  319       3533    ...                Bahamas       ZSA
# 3228                  M80       7056    ...          United States       RFD
# 3234                  M80       7056    ...          United States       YNG
# 3250                  320       3617    ...          United States       LCK
# 3266                  75W       4167    ...                Iceland       KEF
# 3273                  M80       4167    ...          United States       BLV
# 3278                  320       4167    ...          United States       CKB
# 3289                  M80       4167    ...          United States       HGR
# 3299                  M80       4167    ...          United States       OWB
# 3302                  M80       4167    ...          United States       PSM
# 3369                  PA2       3550    ...          United States       VCT
# 3379                  77W       3550    ...                 Russia       DME
# 3383                  ERJ       3550    ...                 Mexico       ACA
# 3391                  CR7       3550    ...          United States       BFL
# 3408                  ERJ       3550    ...                 Mexico       CME
# 3421                  ERJ       3550    ...                 Mexico       DGO
# 3440                  ERJ       3550    ...          United States       HOB
# 3441              ERJ CRJ       3550    ...          United States       HRL
# 3443                  ERJ       3550    ...                 Mexico       HUX
# 3471                  73G       3550    ...                 Mexico       MID
# 3482                  ERJ       3550    ...                 Mexico       OAX
# 3520                  ERJ       3550    ...                 Mexico       SLW
# 3524              CR7 ERJ       3550    ...                 Mexico       TAM
# 3533                  ERJ       3550    ...                 Mexico       VER
# 3535                  CR7       3550    ...                 Mexico       VSA
# 3542                  ERJ       3550    ...                 Mexico       ZIH
# 3543                  ERJ       3550    ...                 Mexico       ZLO
#
#      icao_dest latitude_dest longitude_dest  altitude_dest  timezone_dest  \
# 0         KLWB     37.858299     -80.399498         2302.0           -5.0
# 1         KMCN     32.692799     -83.649200          354.0           -5.0
# 2         KMEI     32.332600     -88.751900          297.0           -6.0
# 3         KMSL     34.745300     -87.610199          551.0           -6.0
# 4         KPIB     31.467100     -89.337097          298.0           -6.0
# 5         KTUP     34.268101     -88.769897          346.0           -6.0
# 6         KAZO     42.234901     -85.552101          874.0           -5.0
# 7         KCHA     35.035301     -85.203796          683.0           -5.0
# 8         KCID     41.884701     -91.710800          869.0           -6.0
# 9         KCRW     38.373100     -81.593201          981.0           -5.0
# 10        KCVG     39.048801     -84.667801          896.0           -5.0
# 11        KEVV     38.036999     -87.532402          418.0           -6.0
# 12        KFWA     40.978500     -85.195099          814.0           -5.0
# 13        KGSO     36.097801     -79.937302          925.0           -5.0
# 14        KGSP     34.895699     -82.218903          964.0           -5.0
# 15        KLAN     42.778702     -84.587402          861.0           -5.0
# 16        KLEX     38.036499     -84.605904          979.0           -5.0
# 17        KMBS     43.532902     -84.079597          668.0           -5.0
# 18        KMSP     44.882000     -93.221802          841.0           -6.0
# 19        KROA     37.325500     -79.975403         1175.0           -5.0
# 20        KSYR     43.111198     -76.106300          421.0           -5.0
# 21        KTYS     35.811001     -83.994003          981.0           -5.0
# 22        KXNA     36.281898     -94.306801         1287.0           -6.0
# 23        KCLT     35.214001     -80.943100          748.0           -5.0
# 24        KDFW     32.896801     -97.038002          607.0           -6.0
# 25        EGLL     51.470600      -0.461941           83.0            0.0
# 26        KMIA     25.793200     -80.290604            8.0           -5.0
# 27        KORD     41.978600     -87.904800          672.0           -6.0
# 28        KPHL     39.871899     -75.241096           36.0           -5.0
# 29        KPHX     33.434299    -112.012001         1135.0           -7.0
# ...        ...           ...            ...            ...            ...
# 3132      KLBE     40.275902     -79.404800         1199.0           -5.0
# 3150      MDST     19.406099     -70.604698          565.0           -4.0
# 3153      MMTO     19.337099     -99.566002         8466.0           -6.0
# 3155      MYSM     24.063299     -74.524002           24.0           -5.0
# 3228      KRFD     42.195400     -89.097198          742.0           -6.0
# 3234      KYNG     41.260700     -80.679100         1192.0           -5.0
# 3250      KLCK     39.813801     -82.927803          744.0           -5.0
# 3266      BIKF     63.985001     -22.605600          171.0            0.0
# 3273      KBLV     38.545200     -89.835197          459.0           -6.0
# 3278      KCKB     39.296600     -80.228104         1217.0           -5.0
# 3289      KHGR     39.707901     -77.729500          703.0           -5.0
# 3299      KOWB     37.740101     -87.166801          407.0           -6.0
# 3302      KPSM     43.077900     -70.823303          100.0           -5.0
# 3369      KVCT     28.852600     -96.918503          115.0           -6.0
# 3379      UUDD     55.408798      37.906300          588.0            3.0
# 3383      MMAA     16.757099     -99.753998           16.0           -6.0
# 3391      KBFL     35.433601    -119.056999          510.0           -8.0
# 3408      MMCE     18.653700     -91.799004           10.0           -6.0
# 3421      MMDO     24.124201    -104.528000         6104.0           -6.0
# 3440      KHOB     32.687500    -103.217003         3661.0           -7.0
# 3441      KHRL     26.228500     -97.654404           36.0           -6.0
# 3443      MMBT     15.775300     -96.262604          464.0           -6.0
# 3471      MMMD     20.937000     -89.657700           38.0           -6.0
# 3482      MMOX     16.999901     -96.726601         4989.0           -6.0
# 3520      MMIO     25.549500    -100.929001         4778.0           -6.0
# 3524      MMTM     22.296400     -97.865898           80.0           -6.0
# 3533      MMVR     19.145901     -96.187302           90.0           -6.0
# 3535      MMVA     17.997000     -92.817398           46.0           -6.0
# 3542      MMZH     17.601601    -101.460999           26.0           -6.0
# 3543      MMZO     19.144800    -104.558998           30.0           -6.0
#
#       dst_dest                tz_dest type_dest
# 0            U       America/New_York   airport
# 1            A       America/New_York   airport
# 2            A        America/Chicago   airport
# 3            A        America/Chicago   airport
# 4            A        America/Chicago   airport
# 5            A        America/Chicago   airport
# 6            A       America/New_York   airport
# 7            A       America/New_York   airport
# 8            A        America/Chicago   airport
# 9            A       America/New_York   airport
# 10           A       America/New_York   airport
# 11           A        America/Chicago   airport
# 12           A       America/New_York   airport
# 13           A       America/New_York   airport
# 14           A       America/New_York   airport
# 15           A       America/New_York   airport
# 16           A       America/New_York   airport
# 17           A       America/New_York   airport
# 18           A        America/Chicago   airport
# 19           A       America/New_York   airport
# 20           A       America/New_York   airport
# 21           A       America/New_York   airport
# 22           A        America/Chicago   airport
# 23           A       America/New_York   airport
# 24           A        America/Chicago   airport
# 25           E          Europe/London   airport
# 26           A       America/New_York   airport
# 27           A        America/Chicago   airport
# 28           A       America/New_York   airport
# 29           N        America/Phoenix   airport
# ...        ...                    ...       ...
# 3132         A       America/New_York   airport
# 3150         U  America/Santo_Domingo   airport
# 3153         S    America/Mexico_City   airport
# 3155         U         America/Nassau   airport
# 3228         A        America/Chicago   airport
# 3234         A       America/New_York   airport
# 3250         A       America/New_York   airport
# 3266         N     Atlantic/Reykjavik   airport
# 3273         A        America/Chicago   airport
# 3278         A       America/New_York   airport
# 3289         A       America/New_York   airport
# 3299         A        America/Chicago   airport
# 3302         A       America/New_York   airport
# 3369         A        America/Chicago   airport
# 3379         N          Europe/Moscow   airport
# 3383         S    America/Mexico_City   airport
# 3391         A    America/Los_Angeles   airport
# 3408         S    America/Mexico_City   airport
# 3421         S    America/Mexico_City   airport
# 3440         A         America/Denver   airport
# 3441         A        America/Chicago   airport
# 3443         S    America/Mexico_City   airport
# 3471         S    America/Mexico_City   airport
# 3482         S    America/Mexico_City   airport
# 3520         S    America/Mexico_City   airport
# 3524         S    America/Mexico_City   airport
# 3533         S    America/Mexico_City   airport
# 3535         S    America/Mexico_City   airport
# 3542         S    America/Mexico_City   airport
# 3543         S    America/Mexico_City   airport
#
# [399 rows x 35 columns]

# %% [markdown]
# That looks better.  Now, let's create a map.  To avoid adding duplicate airports, we are going to use a container called a set.  A set is an unordered collection of unique elements.  This means we can keep adding LEX to the set, and end up with only 1 LEX in the end.

# %%
# create a basic map, centered on Lexington
lex_air_one_stop = folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=4
)

# %%
# create a basic map, centered on Lexington
lex_air = folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=4
)

# %%
# Define some empty sets
airport_set = set()
route_set = set()

# Make sure we don't add duplicates, especially for the origins
for name, row in twoStopLex_routes.iterrows():
    
    if row['source'] not in airport_set: 
        popup_string = row['city_source'] + ' (' + row['source'] + ')'
        marker = folium.CircleMarker([row["latitude_source"], row["longitude_source"]], 
                                     color='MidnightBlue',
                                     fill_color='MidnightBlue', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air_one_stop)
        airport_set.add(row['source'])
        
    if row['dest'] not in airport_set: 
         # popup_string = row['city_dest'] + '(' + row['dest'] + ')'
        marker = folium.CircleMarker([row["latitude_dest"], row["longitude_dest"]], 
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air_one_stop)
        airport_set.add(row['dest'])
    
    # the parentheses in the indicate that we are adding a tuple to the route_set
    if (row['source'],row['dest']) not in route_set:            
        popup_string = row['source'] + '-' + row['dest']        
        line = folium.PolyLine([(row["latitude_source"], row["longitude_source"]), 
                                (row["latitude_dest"], row["longitude_dest"])], 
                                weight=2, color='MidnightBlue'
                                )
        line.add_to(lex_air_one_stop)
        route_set.add((row['source'],row['dest']))
        
lex_air_one_stop.save("lex_air_one_two_stops.html")

# %%
# Define some empty sets
airport_set = set()
route_set = set()

# Make sure we don't add duplicates, especially for the origins
for name, row in oneStopLex_routes.iterrows():
    
    if row['source'] not in airport_set: 
        popup_string = row['city_source'] + ' (' + row['source'] + ')'
        marker = folium.CircleMarker([row["latitude_source"], row["longitude_source"]], 
                                     color='Red',
                                     fill_color='Red', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air_one_stop)
        airport_set.add(row['source'])
        
    if row['dest'] not in airport_set: 
         # popup_string = row['city_dest'] + '(' + row['dest'] + ')'
        marker = folium.CircleMarker([row["latitude_dest"], row["longitude_dest"]], 
                                     color='Brown',
                                     fill_color='Brown', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air_one_stop)
        airport_set.add(row['dest'])
    
    # the parentheses in the indicate that we are adding a tuple to the route_set
    if (row['source'],row['dest']) not in route_set:            
        popup_string = row['source'] + '-' + row['dest']        
        line = folium.PolyLine([(row["latitude_source"], row["longitude_source"]), 
                                (row["latitude_dest"], row["longitude_dest"])], 
                                weight=2, color='brown'
                                )
        line.add_to(lex_air_one_stop)
        route_set.add((row['source'],row['dest']))
        
lex_air_one_stop
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# That's cool.  But airplanes don't fly in a straight line.  They follow the great circle.  So when you fly from Chicago to London, you go over Greenland (which is really pretty on a clear day!).  Can we make the lines follow a great circle?
#
# It looks like there are some options here:
#
# http://gis.stackexchange.com/questions/47/what-tools-in-python-are-available-for-doing-great-circle-distance-line-creati
#
# Let's try one of them.

# %%
import pyproj

# when creating a function, it is good practice to define the API!
def getGreatCirclePoints(startlat, startlon, endlat, endlon): 
    """
    startlat - starting latitude 
    startlon - starting longitude 
    endlat   - ending latitude 
    endlon   - ending longitude 
    
    returns - a list of tuples, where each tuple is the lat-long for a point
              along the curve.  
    """
    # calculate distance between points
    g = pyproj.Geod(ellps='WGS84')
    (az12, az21, dist) = g.inv(startlon, startlat, endlon, endlat)

    # calculate line string along path with segments <= 20 km
    lonlats = g.npts(startlon, startlat, endlon, endlat,
                     1 + int(dist / 20000))

    # the npts function uses lon-lat, while the folium functions use lat-lon
    # This sort of thing is maddening!  What happens is the lines don't show
    # up on the map and you don't know why.  Learn from my mistakes
    latlons = []
    for lon_lat in lonlats: 
        
        # this is how you get values out of a tuple
        (lon, lat) = lon_lat
        
        # add them to our list
        latlons.append((lat, lon)) 
    
    # npts doesn't include start/end points, so prepend/append them
    latlons.insert(0, (startlat, startlon))
    latlons.append((endlat, endlon))
    
    return latlons

# %%
# any time we write a function, we should test that it works
p = getGreatCirclePoints(38.034, -84.500, 33.636700, -84.428101) 
p
# Out:
# [(38.034, -84.5),
#  (37.864933929949096, -84.49708149511396),
#  (37.695862920583586, -84.49417629534568),
#  (37.52678697986378, -84.49128425988357),
#  (37.35770611591111, -84.48840524964173),
#  (37.18862033700805, -84.48553912723197),
#  (37.019529651598035, -84.48268575693639),
#  (36.85043406828536, -84.47984500468044),
#  (36.68133359583508, -84.4770167380065),
#  (36.51222824317288, -84.474200826048),
#  (36.343118019385024, -84.47139713950395),
#  (36.17400293371815, -84.46860555061399),
#  (36.00488299557918, -84.46582593313389),
#  (35.83575821453518, -84.46305816231151),
#  (35.66662860031317, -84.46030211486323),
#  (35.49749416279997, -84.45755766895067),
#  (35.328354912042094, -84.45482470415813),
#  (35.15921085824549, -84.45210310147009),
#  (34.99006201177538, -84.44939274324938),
#  (34.82090838315612, -84.44669351321562),
#  (34.65174998307092, -84.44400529642411),
#  (34.48258682236167, -84.44132797924507),
#  (34.3134189120287, -84.43866144934323),
#  (34.14424626323062, -84.43600559565783),
#  (33.975068887284, -84.43336030838299),
#  (33.805886795663184, -84.4307254789483),
#  (33.6367, -84.428101)]

# %%
# create a basic map, centered on Lexington
lex_air = folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=4
)
lex_air
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
# define the map in the same way, but use great circles for the lines

# Define some empty sets
airport_set = set()
route_set = set()

# Make sure we don't add duplicates, especially for the origins
for name, row in lex_routes.iterrows():
    
    if row['source'] not in airport_set: 
        popup_string = row['city_source'] + ' (' + row['source'] + ')'
        marker = folium.CircleMarker([row["latitude_source"], row["longitude_source"]], 
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['source'])
        
    if row['dest'] not in airport_set: 
        popup_string = row['city_dest'] + '(' + row['dest'] + ')'
        marker = folium.CircleMarker([row["latitude_dest"], row["longitude_dest"]], 
                                     color='MidnightBlue',
                                     fill_color='MidnightBlue', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['dest'])
    
    # PolyLine will accept a whole list of tuples, not just two
    if (row['source'],row['dest']) not in route_set:            
        popup_string = row['source'] + '-' + row['dest']       
        
        gc_points = getGreatCirclePoints(row["latitude_source"], 
                                         row["longitude_source"], 
                                         row["latitude_dest"], 
                                         row["longitude_dest"])
        
        line = folium.PolyLine(gc_points, weight=2, popup=popup_string)
        line.add_to(lex_air)
        route_set.add((row['source'],row['dest']))
        
lex_air
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\shyamalroy\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_value(self, series, key)
#    1985             try:
# -> 1986                 return tslib.get_value_box(s, key)
#    1987             except IndexError:
#
# pandas\tslib.pyx in pandas.tslib.get_value_box (pandas\tslib.c:17017)()
#
# pandas\tslib.pyx in pandas.tslib.get_value_box (pandas\tslib.c:16691)()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-104-7a89dd3b6c1c> in <module>()
#       8 for name, row in lex_routes.iterrows():
#       9
# ---> 10     if row['source'] not in airport_set:
#      11         popup_string = row['city_source'] + ' (' + row['source'] + ')'
#      12         marker = folium.CircleMarker([row["latitude_source"], row["longitude_source"]],
#
# C:\Users\shyamalroy\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     581         key = com._apply_if_callable(key, self)
#     582         try:
# --> 583             result = self.index.get_value(self, key)
#     584
#     585             if not lib.isscalar(result):
#
# C:\Users\shyamalroy\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_value(self, series, key)
#    1992                     raise InvalidIndexError(key)
#    1993                 else:
# -> 1994                     raise e1
#    1995             except Exception:  # pragma: no cover
#    1996                 raise e1
#
# C:\Users\shyamalroy\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_value(self, series, key)
#    1978         try:
#    1979             return self._engine.get_value(s, k,
# -> 1980                                           tz=getattr(series.dtype, 'tz', None))
#    1981         except KeyError as e1:
#    1982             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_value (pandas\index.c:3332)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_value (pandas\index.c:3035)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4018)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12368)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12322)()
#
# KeyError: 'source'

# %%
# save it to its own file
lex_air.save("lex_air.html")

# %% [markdown]
# ### Your turn
#
# The above map shows everywhere you can get to from Lexington on a direct flight.  Your job is to:
#
# 1. Make a map of all the possible destinations with one transfer.
# 2. Make a map of all the possible desitnations with two transfers.
#
# Make the maps look nice!  Use color coding, vary the size of the features, or be selective about what you display in order to communicate the information effectively.
#
# Bonus: This is the air travel version of the Kevin Bacon game.  What is the number N, such that you can reach every airport in the world with N or fewer transfers?
#
# Extra Bonus: Use this very important piece of knowledge to impress your friends at parties!
