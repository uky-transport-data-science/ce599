# %% [markdown]
# # Time-Series Modeling
#
# This lesson is adapted from Sean Abu:
#
# http://www.seanabu.com/2016/03/22/time-series-seasonal-ARIMA-model-in-python/
#
# With examples from Forecasting Principles and Practice, by Hyndman and Athanastopoulos:
#
# https://www.otexts.org/fpp
#
# The latter is an excellent text book and worth checking out.  I also recommend their fpp package for R, which provides some nice functionality to auto-select the order of an ARIMA model.
#
# ### Basics
#
# A time-series is a series of data points indexed in time order.  It is naturally one-dimensional, and for our purposes we will consider that all points are equally spaced.
#
# We may want to model time series for either inference (understanding statistical relationships), or for forecasting.  We may select different approaches depending on our interest.  There are two main approaches we will consider here:
#
# 1. Regression on time-series data. This is about predicting a time series based on exogenous variables.
# 2. ARIMA modeling.  This is about predicting a time series as a function of its past values.
#
# We can also combine the two: ARIMA models with exogenous regressors.
#
# The focus today is on the modeling.  Pandas provides some nice data wrangling methods for working with time series data which are documented here:
#
# http://pandas.pydata.org/pandas-docs/stable/timeseries.html

# %% [markdown]
# ### Regression on time-series data

# %%
# %matplotlib inline

import pandas as pd
import seaborn as sns
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
# This data has
air = pd.read_csv('data/ausair.csv', parse_dates=['YEAR'], index_col='YEAR')
air
# Out:
#                AUSAIR  GUINEARICE
# YEAR
# 1970-01-01   7.318700    0.311405
# 1971-01-01   7.326600    0.325180
# 1972-01-01   7.795600    0.339565
# 1973-01-01   9.384600    0.354580
# 1974-01-01  10.664700    0.370265
# 1975-01-01  11.055100    0.386640
# 1976-01-01  10.864300    0.403740
# 1977-01-01  11.306500    0.421600
# 1978-01-01  12.122300    0.440250
# 1979-01-01  13.022500    0.459720
# 1980-01-01  13.648800    0.480055
# 1981-01-01  13.219500    0.501290
# 1982-01-01  13.187900    0.523460
# 1983-01-01  12.601500    0.546610
# 1984-01-01  13.236800    0.570790
# 1985-01-01  14.412100    0.596035
# 1986-01-01  15.497300    0.622395
# 1987-01-01  16.880200    0.649925
# 1988-01-01  18.816300    0.678670
# 1989-01-01  15.114300    0.708690
# 1990-01-01  17.553400    0.740035
# 1991-01-01  21.860100    0.772765
# 1992-01-01  23.886600    0.806945
# 1993-01-01  26.929300    0.842635
# 1994-01-01  26.888500    0.879905
# 1995-01-01  28.831400    0.918825
# 1996-01-01  30.075100    0.959460
# 1997-01-01  30.953500    1.001900
# 1998-01-01  30.185700    1.046220
# 1999-01-01  31.579700    1.092490
# 2000-01-01  32.577569    1.140810
# 2001-01-01  33.477398    1.033520
# 2002-01-01  39.021581    1.088670
# 2003-01-01  41.386432    1.146760
# 2004-01-01  41.596552    1.207960
# 2005-01-01  44.657324    1.272420
# 2006-01-01  46.951775    1.340310
# 2007-01-01  48.728837    1.401590
# 2008-01-01  51.488427    1.534090
# 2009-01-01  50.026967    1.499000

# %%
# Both time series are growing over the period of interest...

air.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016540A51908>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016540AA8828>], dtype=object)

# %%
# when we plot them against each other, they look to be highly correlated...

sns.jointplot(x="GUINEARICE", y="AUSAIR", data=air)

# %%
# so let's estimate a regression model

mod = smf.ols(formula='AUSAIR ~ GUINEARICE', data=air)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 AUSAIR   R-squared:                       0.971
# Model:                            OLS   Adj. R-squared:                  0.970
# Method:                 Least Squares   F-statistic:                     1272.
# Date:                Thu, 06 Apr 2017   Prob (F-statistic):           7.94e-31
# Time:                        12:12:31   Log-Likelihood:                -89.643
# No. Observations:                  40   AIC:                             183.3
# Df Residuals:                      38   BIC:                             186.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.7297      0.903     -6.348      0.000      -7.557      -3.902
# GUINEARICE    37.4101      1.049     35.672      0.000      35.287      39.533
# ==============================================================================
# Omnibus:                        1.905   Durbin-Watson:                   0.491
# Prob(Omnibus):                  0.386   Jarque-Bera (JB):                1.655
# Skew:                          -0.485   Prob(JB):                        0.437
# Kurtosis:                       2.774   Cond. No.                         4.73
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### Woohoo!  We got an r-squared of 0.97.  This is a great model!  Right?

# %% [markdown]
# Sorry to disappoint, but this is an example of **spurious regression**.  Spurious regression can happen when working with time series that are non-stationary.
#
# I would add that the model lacks a theoretical basis as well.  It clearly falls in the category of "If you can't explain it, you can't use it!"  However, spurious regression can occur even when there is a theoretical basis for the model.
#
# A stationary time series is one whose properties do not depend on the time at which the series is observed.  To avoid spurious regression, we want the dependent variable and all regressors to be stationary.

# %% [markdown]
# One way to tell if data are stationary is to plot them, and look for either a trend or a cycle

# %%
# check for trend or cycle

air.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000165417353C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001654177B0F0>], dtype=object)

# %% [markdown]
# We can also look at plots of the auto-correlation function (ACF).  auto-correlation is the correlation of the time-series past values.  There are some statistical tests for this as well, but often a graphical analysis is good enough.

# %%
# ACF plots

fig = sm.graphics.tsa.plot_acf(air['AUSAIR'], lags=39)
fig = sm.graphics.tsa.plot_acf(air['GUINEARICE'], lags=30)

# %% [markdown]
# What do we do if the data are not stationary?  There are a few strategies, but differencing usually works.  All this means is subtracting each value from the previous value.  That way, you are modeling the change, rather than the total value.

# %%
# shift moves things by the specified number of rows

air['AUSAIR_DIFF'] = air['AUSAIR'] - air['AUSAIR'].shift(1)  
air['GUINEARICE_DIFF'] = air['GUINEARICE'] - air['GUINEARICE'].shift(1)  
air.head()
# Out:
#              AUSAIR  GUINEARICE  AUSAIR_DIFF  GUINEARICE_DIFF
# YEAR
# 1970-01-01   7.3187    0.311405          NaN              NaN
# 1971-01-01   7.3266    0.325180       0.0079         0.013775
# 1972-01-01   7.7956    0.339565       0.4690         0.014385
# 1973-01-01   9.3846    0.354580       1.5890         0.015015
# 1974-01-01  10.6647    0.370265       1.2801         0.015685

# %%
# now does it look stationary? 

air.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000165429006D8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001654297EC18>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000165429CF198>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016542A10710>], dtype=object)

# %%
# ACF plots
# the first row is missing, so skip that one..

fig = sm.graphics.tsa.plot_acf(air['AUSAIR_DIFF'][1:], lags=30)
fig = sm.graphics.tsa.plot_acf(air['GUINEARICE_DIFF'][1:], lags=30)

# %%
# if we have to, we can also calculate a second difference
# don't go beyond 2

air['AUSAIR_2DIFF'] = air['AUSAIR_DIFF'] - air['AUSAIR_DIFF'].shift(1)  
air['GUINEARICE_2DIFF'] = air['GUINEARICE_DIFF'] - air['GUINEARICE_DIFF'].shift(1)  
air.head()
# Out:
#              AUSAIR  GUINEARICE  AUSAIR_DIFF  GUINEARICE_DIFF  AUSAIR_2DIFF  \
# YEAR
# 1970-01-01   7.3187    0.311405          NaN              NaN           NaN
# 1971-01-01   7.3266    0.325180       0.0079         0.013775           NaN
# 1972-01-01   7.7956    0.339565       0.4690         0.014385        0.4611
# 1973-01-01   9.3846    0.354580       1.5890         0.015015        1.1200
# 1974-01-01  10.6647    0.370265       1.2801         0.015685       -0.3089
#
#             GUINEARICE_2DIFF
# YEAR
# 1970-01-01               NaN
# 1971-01-01               NaN
# 1972-01-01           0.00061
# 1973-01-01           0.00063
# 1974-01-01           0.00067

# %%
air.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000016542FACD30>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016543014D30>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000165430636A0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000165430A6780>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000165430F61D0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000016543137048>], dtype=object)

# %%
# ACF plots
# the first two rows are missing, so skip those..

fig = sm.graphics.tsa.plot_acf(air['AUSAIR_2DIFF'][2:], lags=30)
fig = sm.graphics.tsa.plot_acf(air['GUINEARICE_2DIFF'][2:], lags=30)

# %%
# now what if we estimate the same model on the differenced data

mod = smf.ols(formula='AUSAIR_DIFF ~ GUINEARICE_DIFF', data=air)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            AUSAIR_DIFF   R-squared:                       0.125
# Model:                            OLS   Adj. R-squared:                  0.102
# Method:                 Least Squares   F-statistic:                     5.295
# Date:                Thu, 06 Apr 2017   Prob (F-statistic):             0.0271
# Time:                        12:28:00   Log-Likelihood:                -70.079
# No. Observations:                  39   AIC:                             144.2
# Df Residuals:                      37   BIC:                             147.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.5881      0.326      1.806      0.079      -0.072       1.248
# GUINEARICE_DIFF    16.6487      7.235      2.301      0.027       1.988      31.309
# ==============================================================================
# Omnibus:                        6.783   Durbin-Watson:                   1.733
# Prob(Omnibus):                  0.034   Jarque-Bera (JB):               10.436
# Skew:                          -0.123   Prob(JB):                      0.00542
# Kurtosis:                       5.522   Cond. No.                         30.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# now what if we estimate the same model on the second differenced data

mod = smf.ols(formula='AUSAIR_2DIFF ~ GUINEARICE_2DIFF', data=air)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           AUSAIR_2DIFF   R-squared:                       0.164
# Model:                            OLS   Adj. R-squared:                  0.141
# Method:                 Least Squares   F-statistic:                     7.088
# Date:                Thu, 06 Apr 2017   Prob (F-statistic):             0.0115
# Time:                        12:28:44   Log-Likelihood:                -79.187
# No. Observations:                  38   AIC:                             162.4
# Df Residuals:                      36   BIC:                             165.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.0150      0.324     -0.046      0.963      -0.673       0.642
# GUINEARICE_2DIFF    18.3687      6.900      2.662      0.012       4.376      32.362
# ==============================================================================
# Omnibus:                        6.128   Durbin-Watson:                   2.672
# Prob(Omnibus):                  0.047   Jarque-Bera (JB):                8.413
# Skew:                           0.116   Prob(JB):                       0.0149
# Kurtosis:                       5.293   Cond. No.                         21.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Homework
#
# The data folder contains a time-series data set of ridership on the BART rail system from 2001 through 2015.  Estimate a regression model of the ridership (RIDERS) as a function of variables included in the data set.  Build as complete of a model as you can, but be sure you can explain it!

# %%
bartdf = pd.read_csv('data/BARTEstimationFile.csv', parse_dates=['MONTH'], index_col='MONTH')
bartdf.head()
# Out:
#                  RIDERS  STATIONS  CASH_FARE_2010USD_BART  \
# MONTH
# 2001-01-01  321180.5238        39                3.262745
# 2001-02-01  334885.1053        39                3.249754
# 2001-03-01  340021.5455        39                3.242376
# 2001-04-01  333794.4286        39                3.229546
# 2001-05-01  333847.4545        39                3.215007
#
#             AVG_FARE_2010USD_BART           HH      HH_0VEH          POP  \
# MONTH
# 2001-01-01               2.555435  1452556.571  187359.1429  3870692.571
# 2001-02-01               2.545259  1452696.413  187278.4921  3870052.746
# 2001-03-01               2.539481  1452836.254  187197.8413  3869412.921
# 2001-04-01               2.529432  1452976.095  187117.1905  3868773.095
# 2001-05-01               2.518045  1453115.937  187036.5397  3868133.270
#
#                 WORKERS  MEDIAN_HHINC_2010USD  SERVMILES_E_BART     ...       \
# MONTH                                                               ...
# 2001-01-01  1924489.571           85841.07733       25527.10573     ...
# 2001-02-01  1923471.413           85401.59874       25527.10573     ...
# 2001-03-01  1922453.254           85110.28356       25527.10573     ...
# 2001-04-01  1921435.095           84676.45762       25527.10573     ...
# 2001-05-01  1920416.937           84198.65633       25527.10573     ...
#
#             EDHEALTH_EMP  LEISURE_EMP  OTHER_EMP  FUEL_PRICE_2010USD  \
# MONTH
# 2001-01-01      314779.0     179565.0  1317382.0            2.240335
# 2001-02-01      319473.0     181972.0  1321821.0            2.227694
# 2001-03-01      321266.0     184828.0  1331919.0            2.290702
# 2001-04-01      321919.0     185372.0  1308563.0            2.436951
# 2001-05-01      323980.0     188738.0  1302376.0            2.532738
#
#             FUEL_COST_2010USD  TOLL_BB_PK_2010USD  TOLL_BB_OP_2010USD  \
# MONTH
# 2001-01-01           0.101833            2.490645            2.490645
# 2001-02-01           0.101182            2.480728            2.480728
# 2001-03-01           0.103965            2.475096            2.475096
# 2001-04-01           0.110519            2.465302            2.465302
# 2001-05-01           0.114777            2.454204            2.454204
#
#             TOLL_BB_CARPOOL_2010USD  CASUAL_CARPOOL  BART_STRIKE
# MONTH
# 2001-01-01                      0.0               1            0
# 2001-02-01                      0.0               1            0
# 2001-03-01                      0.0               1            0
# 2001-04-01                      0.0               1            0
# 2001-05-01                      0.0               1            0
#
# [5 rows x 22 columns]

# %%
bartdf[['RIDERS','FUEL_PRICE_2010USD']].plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000225D17DDDA0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000225D18136D8>], dtype=object)

# %%
bartdf['CASH_FARE_2010USD_BART'].plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000225D2A08BA8>], dtype=object)

# %%
fig = sm.graphics.tsa.plot_acf(bartdf['RIDERS'], lags=176)

# %%
fig = sm.graphics.tsa.plot_acf(bartdf['CASH_FARE_2010USD_BART'], lags=150)

# %%
bartdf['RIDERS_DIFF'] = bartdf['RIDERS'] - bartdf['RIDERS'].shift(12)  
bartdf.head(45)
# Out:
#                  RIDERS  STATIONS  CASH_FARE_2010USD_BART  \
# MONTH
# 2001-01-01  321180.5238        39                3.262745
# 2001-02-01  334885.1053        39                3.249754
# 2001-03-01  340021.5455        39                3.242376
# 2001-04-01  333794.4286        39                3.229546
# 2001-05-01  333847.4545        39                3.215007
# 2001-06-01  329447.8095        39                3.209588
# 2001-07-01  324565.6000        39                3.218629
# 2001-08-01  321757.9130        39                3.218629
# 2001-09-01  321320.8421        39                3.204188
# 2001-10-01  315571.1818        39                3.215007
# 2001-11-01  317824.9474        39                3.220444
# 2001-12-01  292390.7222        39                3.233202
# 2002-01-01  300937.5714        39                3.225899
# 2002-02-01  307748.1579        39                3.213199
# 2002-03-01  305536.8571        39                3.195228
# 2002-04-01  311872.9545        39                3.177457
# 2002-05-01  304468.2727        39                3.177457
# 2002-06-01  302729.9000        39                3.175690
# 2002-07-01  300920.6190        39                3.172164
# 2002-08-01  296473.0455        39                3.161631
# 2002-09-01  309639.7500        39                3.156391
# 2002-10-01  303796.3182        39                3.151168
# 2002-11-01  294359.9444        39                3.151168
# 2002-12-01  282622.3158        39                3.158136
# 2003-01-01  288637.6190        39                3.312243
# 2003-02-01  295525.4737        39                3.286917
# 2003-03-01  296029.8095        39                3.267289
# 2003-04-01  292949.1364        39                3.274399
# 2003-05-01  289680.9048        39                3.279752
# 2003-06-01  290310.0000        43                3.276182
# 2003-07-01  298911.4545        43                3.272619
# 2003-08-01  302388.2857        43                3.260209
# 2003-09-01  313681.9524        43                3.249647
# 2003-10-01  315790.7727        43                3.253160
# 2003-11-01  308965.8824        43                3.261976
# 2003-12-01  296470.4737        43                3.265516
# 2004-01-01  296820.2105        43                3.579321
# 2004-02-01  305248.2632        43                3.560098
# 2004-03-01  308214.2609        43                3.537301
# 2004-04-01  310871.5909        43                3.526012
# 2004-05-01  310777.2500        43                3.505501
# 2004-06-01  308792.5455        43                3.494413
# 2004-07-01  308189.9524        43                3.499948
# 2004-08-01  304724.3182        43                3.498102
# 2004-09-01  323235.5714        43                3.490733
#
#             AVG_FARE_2010USD_BART           HH      HH_0VEH          POP  \
# MONTH
# 2001-01-01               2.555435  1452556.571  187359.1429  3870692.571
# 2001-02-01               2.545259  1452696.413  187278.4921  3870052.746
# 2001-03-01               2.539481  1452836.254  187197.8413  3869412.921
# 2001-04-01               2.529432  1452976.095  187117.1905  3868773.095
# 2001-05-01               2.518045  1453115.937  187036.5397  3868133.270
# 2001-06-01               2.513801  1453255.778  186955.8889  3867493.444
# 2001-07-01               2.443754  1453395.619  186875.2381  3866853.619
# 2001-08-01               2.443754  1453535.460  186794.5873  3866213.794
# 2001-09-01               2.432790  1453675.302  186713.9365  3865573.968
# 2001-10-01               2.441004  1453815.143  186633.2857  3864934.143
# 2001-11-01               2.445132  1453954.984  186552.6349  3864294.317
# 2001-12-01               2.454818  1454094.825  186471.9841  3863654.492
# 2002-01-01               2.449274  1454234.667  186391.3333  3863014.667
# 2002-02-01               2.439631  1454374.508  186310.6825  3862374.841
# 2002-03-01               2.425986  1454514.349  186230.0317  3861735.016
# 2002-04-01               2.412494  1454654.190  186149.3810  3861095.190
# 2002-05-01               2.412494  1454794.032  186068.7302  3860455.365
# 2002-06-01               2.411153  1454933.873  185988.0794  3859815.540
# 2002-07-01               2.405660  1455073.714  185907.4286  3859175.714
# 2002-08-01               2.397673  1455213.556  185826.7778  3858535.889
# 2002-09-01               2.393699  1455353.397  185746.1270  3857896.063
# 2002-10-01               2.389738  1455493.238  185665.4762  3857256.238
# 2002-11-01               2.389738  1455633.079  185584.8254  3856616.413
# 2002-12-01               2.395022  1455772.921  185504.1746  3855976.587
# 2003-01-01               2.511892  1455912.762  185423.5238  3855336.762
# 2003-02-01               2.492685  1456052.603  185342.8730  3854696.937
# 2003-03-01               2.477800  1456192.444  185262.2222  3854057.111
# 2003-04-01               2.483192  1456332.286  185181.5714  3853417.286
# 2003-05-01               2.487252  1456472.127  185100.9206  3852777.460
# 2003-06-01               2.484544  1456611.968  185020.2698  3852137.635
# 2003-07-01               2.544023  1456751.810  184939.6190  3851497.810
# 2003-08-01               2.534376  1456891.651  184858.9683  3850857.984
# 2003-09-01               2.526166  1457031.492  184778.3175  3850218.159
# 2003-10-01               2.528897  1457171.333  184697.6667  3849578.333
# 2003-11-01               2.535750  1457311.175  184617.0159  3848938.508
# 2003-12-01               2.538502  1457451.016  184536.3651  3848298.683
# 2004-01-01               2.782443  1457590.857  184455.7143  3847658.857
# 2004-02-01               2.767500  1457730.698  184375.0635  3847019.032
# 2004-03-01               2.749778  1457870.540  184294.4127  3846379.206
# 2004-04-01               2.741003  1458010.381  184213.7619  3845739.381
# 2004-05-01               2.725058  1458150.222  184133.1111  3845099.556
# 2004-06-01               2.716439  1458290.063  184052.4603  3844459.730
# 2004-07-01               2.702821  1458429.905  183971.8095  3843819.905
# 2004-08-01               2.701394  1458569.746  183891.1587  3843180.079
# 2004-09-01               2.695704  1458709.587  183810.5079  3842540.254
#
#                 WORKERS  MEDIAN_HHINC_2010USD  SERVMILES_E_BART     ...       \
# MONTH                                                               ...
# 2001-01-01  1924489.571           85841.07733       25527.10573     ...
# 2001-02-01  1923471.413           85401.59874       25527.10573     ...
# 2001-03-01  1922453.254           85110.28356       25527.10573     ...
# 2001-04-01  1921435.095           84676.45762       25527.10573     ...
# 2001-05-01  1920416.937           84198.65633       25527.10573     ...
# 2001-06-01  1919398.778           83960.33478       25527.10573     ...
# 2001-07-01  1918380.619           84100.17146       25382.03327     ...
# 2001-08-01  1917362.460           84003.51416       25382.03327     ...
# 2001-09-01  1916344.302           83530.39581       25382.03327     ...
# 2001-10-01  1915326.143           83715.91371       25382.03327     ...
# 2001-11-01  1914307.984           83760.81533       25382.03327     ...
# 2001-12-01  1913289.825           83995.59646       25382.03327     ...
# 2002-01-01  1912271.667           83709.07751       25382.03327     ...
# 2002-02-01  1911253.508           83283.10372       25382.03327     ...
# 2002-03-01  1910235.349           82721.45711       25382.03327     ...
# 2002-04-01  1909217.190           82166.07175       25382.03327     ...
# 2002-05-01  1908199.032           82070.77501       25382.03327     ...
# 2002-06-01  1907180.873           81929.92478       25382.03327     ...
# 2002-07-01  1906162.714           81743.83157       25574.88408     ...
# 2002-08-01  1905144.556           81377.62666       25574.88408     ...
# 2002-09-01  1904126.397           81148.13637       25574.88408     ...
# 2002-10-01  1903108.238           80919.41921       25574.88408     ...
# 2002-11-01  1902090.079           80824.99280       25574.88408     ...
# 2002-12-01  1901071.921           80909.08877       25574.88408     ...
# 2003-01-01  1900053.762           80458.66590       25574.88408     ...
# 2003-02-01  1899035.603           79750.01365       25574.88408     ...
# 2003-03-01  1898017.444           79180.87879       25574.88408     ...
# 2003-04-01  1896999.286           79260.12360       25574.88408     ...
# 2003-05-01  1895981.127           79296.49063       25574.88408     ...
# 2003-06-01  1894962.968           79117.05939       25574.88408     ...
# 2003-07-01  1893944.810           78938.03185       27091.62964     ...
# 2003-08-01  1892926.651           78546.08218       27091.62964     ...
# 2003-09-01  1891908.492           78199.30858       27091.62964     ...
# 2003-10-01  1890890.333           78191.45726       27091.62964     ...
# 2003-11-01  1889872.175           78310.73008       27091.62964     ...
# 2003-12-01  1888854.016           78302.99659       27091.62964     ...
# 2004-01-01  1887835.857           77830.22302       27091.62964     ...
# 2004-02-01  1886817.698           77320.48764       27091.62964     ...
# 2004-03-01  1885799.540           76734.23029       27091.62964     ...
# 2004-04-01  1884781.381           76398.49560       27091.62964     ...
# 2004-05-01  1883763.222           75863.78662       27091.62964     ...
# 2004-06-01  1882745.063           75533.83967       27091.62964     ...
# 2004-07-01  1881726.905           75563.35364       26062.65764     ...
# 2004-08-01  1880708.746           75433.41125       26062.65764     ...
# 2004-09-01  1879690.587           75184.65583       26062.65764     ...
#
#             LEISURE_EMP  OTHER_EMP  FUEL_PRICE_2010USD  FUEL_COST_2010USD  \
# MONTH
# 2001-01-01     179565.0  1317382.0            2.240335           0.101833
# 2001-02-01     181972.0  1321821.0            2.227694           0.101182
# 2001-03-01     184828.0  1331919.0            2.290702           0.103965
# 2001-04-01     185372.0  1308563.0            2.436951           0.110519
# 2001-05-01     188738.0  1302376.0            2.532738           0.114777
# 2001-06-01     190404.0  1306233.0            2.524794           0.114330
# 2001-07-01     190728.0  1285061.0            2.369747           0.107228
# 2001-08-01     191763.0  1279206.0            2.137563           0.096759
# 2001-09-01     188124.0  1269755.0            2.291850           0.103782
# 2001-10-01     183662.0  1252495.0            2.187923           0.099113
# 2001-11-01     181134.0  1242913.0            2.012163           0.091186
# 2001-12-01     181322.0  1246095.0            1.737537           0.078770
# 2002-01-01     174351.0  1205437.0            1.632650           0.074043
# 2002-02-01     175744.0  1209295.0            1.610279           0.073056
# 2002-03-01     178948.0  1218255.0            1.843963           0.083690
# 2002-04-01     183415.0  1211173.0            2.070198           0.093993
# 2002-05-01     187507.0  1213053.0            2.030177           0.092211
# 2002-06-01     189436.0  1220165.0            2.059350           0.093571
# 2002-07-01     188328.0  1211479.0            2.084911           0.094769
# 2002-08-01     190441.0  1212595.0            2.067127           0.093889
# 2002-09-01     188062.0  1209551.0            2.028764           0.092077
# 2002-10-01     186099.0  1195900.0            1.974892           0.089564
# 2002-11-01     185376.0  1197978.0            2.063895           0.093530
# 2002-12-01     185005.0  1205339.0            2.039529           0.092356
# 2003-01-01     178796.0  1168936.0            2.137357           0.096713
# 2003-02-01     179774.0  1172937.0            2.324660           0.105109
# 2003-03-01     181228.0  1178783.0            2.604360           0.117667
# 2003-04-01     182618.0  1170767.0            2.528168           0.114139
# 2003-05-01     185187.0  1169112.0            2.323158           0.104804
# 2003-06-01     188544.0  1173883.0            2.252968           0.101561
# 2003-07-01     187421.0  1169054.0            2.252890           0.101482
# 2003-08-01     190259.0  1171082.0            2.350658           0.105766
# 2003-09-01     188525.0  1167570.0            2.503170           0.112502
# 2003-10-01     186984.0  1160561.0            2.241851           0.100644
# 2003-11-01     184469.0  1160329.0            2.099011           0.094126
# 2003-12-01     185728.0  1165292.0            2.005453           0.089830
# 2004-01-01     177932.0  1134343.0            2.059287           0.092138
# 2004-02-01     180368.0  1139391.0            2.262536           0.101119
# 2004-03-01     182543.0  1146497.0            2.538944           0.113346
# 2004-04-01     184638.0  1146019.0            2.545920           0.113530
# 2004-05-01     188589.0  1149334.0            2.672945           0.119062
# 2004-06-01     189892.0  1156969.0            2.704722           0.120344
# 2004-07-01     191649.0  1160014.0            2.596179           0.115386
# 2004-08-01     192335.0  1160088.0            2.482041           0.110477
# 2004-09-01     192516.0  1157301.0            2.463034           0.109793
#
#             TOLL_BB_PK_2010USD  TOLL_BB_OP_2010USD  TOLL_BB_CARPOOL_2010USD  \
# MONTH
# 2001-01-01            2.490645            2.490645                      0.0
# 2001-02-01            2.480728            2.480728                      0.0
# 2001-03-01            2.475096            2.475096                      0.0
# 2001-04-01            2.465302            2.465302                      0.0
# 2001-05-01            2.454204            2.454204                      0.0
# 2001-06-01            2.450067            2.450067                      0.0
# 2001-07-01            2.456969            2.456969                      0.0
# 2001-08-01            2.456969            2.456969                      0.0
# 2001-09-01            2.445945            2.445945                      0.0
# 2001-10-01            2.454204            2.454204                      0.0
# 2001-11-01            2.458354            2.458354                      0.0
# 2001-12-01            2.468093            2.468093                      0.0
# 2002-01-01            2.462518            2.462518                      0.0
# 2002-02-01            2.452823            2.452823                      0.0
# 2002-03-01            2.439105            2.439105                      0.0
# 2002-04-01            2.425539            2.425539                      0.0
# 2002-05-01            2.425539            2.425539                      0.0
# 2002-06-01            2.424191            2.424191                      0.0
# 2002-07-01            2.421499            2.421499                      0.0
# 2002-08-01            2.413459            2.413459                      0.0
# 2002-09-01            2.409459            2.409459                      0.0
# 2002-10-01            2.405472            2.405472                      0.0
# 2002-11-01            2.405472            2.405472                      0.0
# 2002-12-01            2.410790            2.410790                      0.0
# 2003-01-01            2.400176            2.400176                      0.0
# 2003-02-01            2.381824            2.381824                      0.0
# 2003-03-01            2.367600            2.367600                      0.0
# 2003-04-01            2.372753            2.372753                      0.0
# 2003-05-01            2.376632            2.376632                      0.0
# 2003-06-01            2.374045            2.374045                      0.0
# 2003-07-01            2.371463            2.371463                      0.0
# 2003-08-01            2.362470            2.362470                      0.0
# 2003-09-01            2.354816            2.354816                      0.0
# 2003-10-01            2.357362            2.357362                      0.0
# 2003-11-01            2.363751            2.363751                      0.0
# 2003-12-01            2.366316            2.366316                      0.0
# 2004-01-01            2.354816            2.354816                      0.0
# 2004-02-01            2.342170            2.342170                      0.0
# 2004-03-01            2.327172            2.327172                      0.0
# 2004-04-01            2.319745            2.319745                      0.0
# 2004-05-01            2.306251            2.306251                      0.0
# 2004-06-01            2.298956            2.298956                      0.0
# 2004-07-01            3.453897            3.453897                      0.0
# 2004-08-01            3.452074            3.452074                      0.0
# 2004-09-01            3.444803            3.444803                      0.0
#
#             CASUAL_CARPOOL  BART_STRIKE  RIDERS_DIFF
# MONTH
# 2001-01-01               1            0          NaN
# 2001-02-01               1            0          NaN
# 2001-03-01               1            0          NaN
# 2001-04-01               1            0          NaN
# 2001-05-01               1            0          NaN
# 2001-06-01               1            0          NaN
# 2001-07-01               1            0          NaN
# 2001-08-01               1            0          NaN
# 2001-09-01               1            0          NaN
# 2001-10-01               1            0          NaN
# 2001-11-01               1            0          NaN
# 2001-12-01               1            0          NaN
# 2002-01-01               1            0  -20242.9524
# 2002-02-01               1            0  -27136.9474
# 2002-03-01               1            0  -34484.6884
# 2002-04-01               1            0  -21921.4741
# 2002-05-01               1            0  -29379.1818
# 2002-06-01               1            0  -26717.9095
# 2002-07-01               1            0  -23644.9810
# 2002-08-01               1            0  -25284.8675
# 2002-09-01               1            0  -11681.0921
# 2002-10-01               1            0  -11774.8636
# 2002-11-01               1            0  -23465.0030
# 2002-12-01               1            0   -9768.4064
# 2003-01-01               1            0  -12299.9524
# 2003-02-01               1            0  -12222.6842
# 2003-03-01               1            0   -9507.0476
# 2003-04-01               1            0  -18923.8181
# 2003-05-01               1            0  -14787.3679
# 2003-06-01               1            0  -12419.9000
# 2003-07-01               1            0   -2009.1645
# 2003-08-01               1            0    5915.2402
# 2003-09-01               1            0    4042.2024
# 2003-10-01               1            0   11994.4545
# 2003-11-01               1            0   14605.9380
# 2003-12-01               1            0   13848.1579
# 2004-01-01               1            0    8182.5915
# 2004-02-01               1            0    9722.7895
# 2004-03-01               1            0   12184.4514
# 2004-04-01               1            0   17922.4545
# 2004-05-01               1            0   21096.3452
# 2004-06-01               1            0   18482.5455
# 2004-07-01               1            0    9278.4979
# 2004-08-01               1            0    2336.0325
# 2004-09-01               1            0    9553.6190
#
# [45 rows x 23 columns]

# %%
fig = sm.graphics.tsa.plot_acf(bartdf['RIDERS_DIFF'], lags=176)

# %%
fig = sm.graphics.tsa.plot_acf(bartdf['SERVMILES_E_BART'], lags=176)

# %%
bartdf['SERVMILES_DIFF'] = bartdf['SERVMILES_E_BART'] - bartdf['SERVMILES_E_BART'].shift(12)  
bartdf.head(45)
# Out:
#                  RIDERS  STATIONS  CASH_FARE_2010USD_BART  \
# MONTH
# 2001-01-01  321180.5238        39                3.262745
# 2001-02-01  334885.1053        39                3.249754
# 2001-03-01  340021.5455        39                3.242376
# 2001-04-01  333794.4286        39                3.229546
# 2001-05-01  333847.4545        39                3.215007
# 2001-06-01  329447.8095        39                3.209588
# 2001-07-01  324565.6000        39                3.218629
# 2001-08-01  321757.9130        39                3.218629
# 2001-09-01  321320.8421        39                3.204188
# 2001-10-01  315571.1818        39                3.215007
# 2001-11-01  317824.9474        39                3.220444
# 2001-12-01  292390.7222        39                3.233202
# 2002-01-01  300937.5714        39                3.225899
# 2002-02-01  307748.1579        39                3.213199
# 2002-03-01  305536.8571        39                3.195228
# 2002-04-01  311872.9545        39                3.177457
# 2002-05-01  304468.2727        39                3.177457
# 2002-06-01  302729.9000        39                3.175690
# 2002-07-01  300920.6190        39                3.172164
# 2002-08-01  296473.0455        39                3.161631
# 2002-09-01  309639.7500        39                3.156391
# 2002-10-01  303796.3182        39                3.151168
# 2002-11-01  294359.9444        39                3.151168
# 2002-12-01  282622.3158        39                3.158136
# 2003-01-01  288637.6190        39                3.312243
# 2003-02-01  295525.4737        39                3.286917
# 2003-03-01  296029.8095        39                3.267289
# 2003-04-01  292949.1364        39                3.274399
# 2003-05-01  289680.9048        39                3.279752
# 2003-06-01  290310.0000        43                3.276182
# 2003-07-01  298911.4545        43                3.272619
# 2003-08-01  302388.2857        43                3.260209
# 2003-09-01  313681.9524        43                3.249647
# 2003-10-01  315790.7727        43                3.253160
# 2003-11-01  308965.8824        43                3.261976
# 2003-12-01  296470.4737        43                3.265516
# 2004-01-01  296820.2105        43                3.579321
# 2004-02-01  305248.2632        43                3.560098
# 2004-03-01  308214.2609        43                3.537301
# 2004-04-01  310871.5909        43                3.526012
# 2004-05-01  310777.2500        43                3.505501
# 2004-06-01  308792.5455        43                3.494413
# 2004-07-01  308189.9524        43                3.499948
# 2004-08-01  304724.3182        43                3.498102
# 2004-09-01  323235.5714        43                3.490733
#
#             AVG_FARE_2010USD_BART           HH      HH_0VEH          POP  \
# MONTH
# 2001-01-01               2.555435  1452556.571  187359.1429  3870692.571
# 2001-02-01               2.545259  1452696.413  187278.4921  3870052.746
# 2001-03-01               2.539481  1452836.254  187197.8413  3869412.921
# 2001-04-01               2.529432  1452976.095  187117.1905  3868773.095
# 2001-05-01               2.518045  1453115.937  187036.5397  3868133.270
# 2001-06-01               2.513801  1453255.778  186955.8889  3867493.444
# 2001-07-01               2.443754  1453395.619  186875.2381  3866853.619
# 2001-08-01               2.443754  1453535.460  186794.5873  3866213.794
# 2001-09-01               2.432790  1453675.302  186713.9365  3865573.968
# 2001-10-01               2.441004  1453815.143  186633.2857  3864934.143
# 2001-11-01               2.445132  1453954.984  186552.6349  3864294.317
# 2001-12-01               2.454818  1454094.825  186471.9841  3863654.492
# 2002-01-01               2.449274  1454234.667  186391.3333  3863014.667
# 2002-02-01               2.439631  1454374.508  186310.6825  3862374.841
# 2002-03-01               2.425986  1454514.349  186230.0317  3861735.016
# 2002-04-01               2.412494  1454654.190  186149.3810  3861095.190
# 2002-05-01               2.412494  1454794.032  186068.7302  3860455.365
# 2002-06-01               2.411153  1454933.873  185988.0794  3859815.540
# 2002-07-01               2.405660  1455073.714  185907.4286  3859175.714
# 2002-08-01               2.397673  1455213.556  185826.7778  3858535.889
# 2002-09-01               2.393699  1455353.397  185746.1270  3857896.063
# 2002-10-01               2.389738  1455493.238  185665.4762  3857256.238
# 2002-11-01               2.389738  1455633.079  185584.8254  3856616.413
# 2002-12-01               2.395022  1455772.921  185504.1746  3855976.587
# 2003-01-01               2.511892  1455912.762  185423.5238  3855336.762
# 2003-02-01               2.492685  1456052.603  185342.8730  3854696.937
# 2003-03-01               2.477800  1456192.444  185262.2222  3854057.111
# 2003-04-01               2.483192  1456332.286  185181.5714  3853417.286
# 2003-05-01               2.487252  1456472.127  185100.9206  3852777.460
# 2003-06-01               2.484544  1456611.968  185020.2698  3852137.635
# 2003-07-01               2.544023  1456751.810  184939.6190  3851497.810
# 2003-08-01               2.534376  1456891.651  184858.9683  3850857.984
# 2003-09-01               2.526166  1457031.492  184778.3175  3850218.159
# 2003-10-01               2.528897  1457171.333  184697.6667  3849578.333
# 2003-11-01               2.535750  1457311.175  184617.0159  3848938.508
# 2003-12-01               2.538502  1457451.016  184536.3651  3848298.683
# 2004-01-01               2.782443  1457590.857  184455.7143  3847658.857
# 2004-02-01               2.767500  1457730.698  184375.0635  3847019.032
# 2004-03-01               2.749778  1457870.540  184294.4127  3846379.206
# 2004-04-01               2.741003  1458010.381  184213.7619  3845739.381
# 2004-05-01               2.725058  1458150.222  184133.1111  3845099.556
# 2004-06-01               2.716439  1458290.063  184052.4603  3844459.730
# 2004-07-01               2.702821  1458429.905  183971.8095  3843819.905
# 2004-08-01               2.701394  1458569.746  183891.1587  3843180.079
# 2004-09-01               2.695704  1458709.587  183810.5079  3842540.254
#
#                 WORKERS  MEDIAN_HHINC_2010USD  SERVMILES_E_BART  \
# MONTH
# 2001-01-01  1924489.571           85841.07733       25527.10573
# 2001-02-01  1923471.413           85401.59874       25527.10573
# 2001-03-01  1922453.254           85110.28356       25527.10573
# 2001-04-01  1921435.095           84676.45762       25527.10573
# 2001-05-01  1920416.937           84198.65633       25527.10573
# 2001-06-01  1919398.778           83960.33478       25527.10573
# 2001-07-01  1918380.619           84100.17146       25382.03327
# 2001-08-01  1917362.460           84003.51416       25382.03327
# 2001-09-01  1916344.302           83530.39581       25382.03327
# 2001-10-01  1915326.143           83715.91371       25382.03327
# 2001-11-01  1914307.984           83760.81533       25382.03327
# 2001-12-01  1913289.825           83995.59646       25382.03327
# 2002-01-01  1912271.667           83709.07751       25382.03327
# 2002-02-01  1911253.508           83283.10372       25382.03327
# 2002-03-01  1910235.349           82721.45711       25382.03327
# 2002-04-01  1909217.190           82166.07175       25382.03327
# 2002-05-01  1908199.032           82070.77501       25382.03327
# 2002-06-01  1907180.873           81929.92478       25382.03327
# 2002-07-01  1906162.714           81743.83157       25574.88408
# 2002-08-01  1905144.556           81377.62666       25574.88408
# 2002-09-01  1904126.397           81148.13637       25574.88408
# 2002-10-01  1903108.238           80919.41921       25574.88408
# 2002-11-01  1902090.079           80824.99280       25574.88408
# 2002-12-01  1901071.921           80909.08877       25574.88408
# 2003-01-01  1900053.762           80458.66590       25574.88408
# 2003-02-01  1899035.603           79750.01365       25574.88408
# 2003-03-01  1898017.444           79180.87879       25574.88408
# 2003-04-01  1896999.286           79260.12360       25574.88408
# 2003-05-01  1895981.127           79296.49063       25574.88408
# 2003-06-01  1894962.968           79117.05939       25574.88408
# 2003-07-01  1893944.810           78938.03185       27091.62964
# 2003-08-01  1892926.651           78546.08218       27091.62964
# 2003-09-01  1891908.492           78199.30858       27091.62964
# 2003-10-01  1890890.333           78191.45726       27091.62964
# 2003-11-01  1889872.175           78310.73008       27091.62964
# 2003-12-01  1888854.016           78302.99659       27091.62964
# 2004-01-01  1887835.857           77830.22302       27091.62964
# 2004-02-01  1886817.698           77320.48764       27091.62964
# 2004-03-01  1885799.540           76734.23029       27091.62964
# 2004-04-01  1884781.381           76398.49560       27091.62964
# 2004-05-01  1883763.222           75863.78662       27091.62964
# 2004-06-01  1882745.063           75533.83967       27091.62964
# 2004-07-01  1881726.905           75563.35364       26062.65764
# 2004-08-01  1880708.746           75433.41125       26062.65764
# 2004-09-01  1879690.587           75184.65583       26062.65764
#
#                  ...        OTHER_EMP  FUEL_PRICE_2010USD  FUEL_COST_2010USD  \
# MONTH            ...
# 2001-01-01       ...        1317382.0            2.240335           0.101833
# 2001-02-01       ...        1321821.0            2.227694           0.101182
# 2001-03-01       ...        1331919.0            2.290702           0.103965
# 2001-04-01       ...        1308563.0            2.436951           0.110519
# 2001-05-01       ...        1302376.0            2.532738           0.114777
# 2001-06-01       ...        1306233.0            2.524794           0.114330
# 2001-07-01       ...        1285061.0            2.369747           0.107228
# 2001-08-01       ...        1279206.0            2.137563           0.096759
# 2001-09-01       ...        1269755.0            2.291850           0.103782
# 2001-10-01       ...        1252495.0            2.187923           0.099113
# 2001-11-01       ...        1242913.0            2.012163           0.091186
# 2001-12-01       ...        1246095.0            1.737537           0.078770
# 2002-01-01       ...        1205437.0            1.632650           0.074043
# 2002-02-01       ...        1209295.0            1.610279           0.073056
# 2002-03-01       ...        1218255.0            1.843963           0.083690
# 2002-04-01       ...        1211173.0            2.070198           0.093993
# 2002-05-01       ...        1213053.0            2.030177           0.092211
# 2002-06-01       ...        1220165.0            2.059350           0.093571
# 2002-07-01       ...        1211479.0            2.084911           0.094769
# 2002-08-01       ...        1212595.0            2.067127           0.093889
# 2002-09-01       ...        1209551.0            2.028764           0.092077
# 2002-10-01       ...        1195900.0            1.974892           0.089564
# 2002-11-01       ...        1197978.0            2.063895           0.093530
# 2002-12-01       ...        1205339.0            2.039529           0.092356
# 2003-01-01       ...        1168936.0            2.137357           0.096713
# 2003-02-01       ...        1172937.0            2.324660           0.105109
# 2003-03-01       ...        1178783.0            2.604360           0.117667
# 2003-04-01       ...        1170767.0            2.528168           0.114139
# 2003-05-01       ...        1169112.0            2.323158           0.104804
# 2003-06-01       ...        1173883.0            2.252968           0.101561
# 2003-07-01       ...        1169054.0            2.252890           0.101482
# 2003-08-01       ...        1171082.0            2.350658           0.105766
# 2003-09-01       ...        1167570.0            2.503170           0.112502
# 2003-10-01       ...        1160561.0            2.241851           0.100644
# 2003-11-01       ...        1160329.0            2.099011           0.094126
# 2003-12-01       ...        1165292.0            2.005453           0.089830
# 2004-01-01       ...        1134343.0            2.059287           0.092138
# 2004-02-01       ...        1139391.0            2.262536           0.101119
# 2004-03-01       ...        1146497.0            2.538944           0.113346
# 2004-04-01       ...        1146019.0            2.545920           0.113530
# 2004-05-01       ...        1149334.0            2.672945           0.119062
# 2004-06-01       ...        1156969.0            2.704722           0.120344
# 2004-07-01       ...        1160014.0            2.596179           0.115386
# 2004-08-01       ...        1160088.0            2.482041           0.110477
# 2004-09-01       ...        1157301.0            2.463034           0.109793
#
#             TOLL_BB_PK_2010USD  TOLL_BB_OP_2010USD  TOLL_BB_CARPOOL_2010USD  \
# MONTH
# 2001-01-01            2.490645            2.490645                      0.0
# 2001-02-01            2.480728            2.480728                      0.0
# 2001-03-01            2.475096            2.475096                      0.0
# 2001-04-01            2.465302            2.465302                      0.0
# 2001-05-01            2.454204            2.454204                      0.0
# 2001-06-01            2.450067            2.450067                      0.0
# 2001-07-01            2.456969            2.456969                      0.0
# 2001-08-01            2.456969            2.456969                      0.0
# 2001-09-01            2.445945            2.445945                      0.0
# 2001-10-01            2.454204            2.454204                      0.0
# 2001-11-01            2.458354            2.458354                      0.0
# 2001-12-01            2.468093            2.468093                      0.0
# 2002-01-01            2.462518            2.462518                      0.0
# 2002-02-01            2.452823            2.452823                      0.0
# 2002-03-01            2.439105            2.439105                      0.0
# 2002-04-01            2.425539            2.425539                      0.0
# 2002-05-01            2.425539            2.425539                      0.0
# 2002-06-01            2.424191            2.424191                      0.0
# 2002-07-01            2.421499            2.421499                      0.0
# 2002-08-01            2.413459            2.413459                      0.0
# 2002-09-01            2.409459            2.409459                      0.0
# 2002-10-01            2.405472            2.405472                      0.0
# 2002-11-01            2.405472            2.405472                      0.0
# 2002-12-01            2.410790            2.410790                      0.0
# 2003-01-01            2.400176            2.400176                      0.0
# 2003-02-01            2.381824            2.381824                      0.0
# 2003-03-01            2.367600            2.367600                      0.0
# 2003-04-01            2.372753            2.372753                      0.0
# 2003-05-01            2.376632            2.376632                      0.0
# 2003-06-01            2.374045            2.374045                      0.0
# 2003-07-01            2.371463            2.371463                      0.0
# 2003-08-01            2.362470            2.362470                      0.0
# 2003-09-01            2.354816            2.354816                      0.0
# 2003-10-01            2.357362            2.357362                      0.0
# 2003-11-01            2.363751            2.363751                      0.0
# 2003-12-01            2.366316            2.366316                      0.0
# 2004-01-01            2.354816            2.354816                      0.0
# 2004-02-01            2.342170            2.342170                      0.0
# 2004-03-01            2.327172            2.327172                      0.0
# 2004-04-01            2.319745            2.319745                      0.0
# 2004-05-01            2.306251            2.306251                      0.0
# 2004-06-01            2.298956            2.298956                      0.0
# 2004-07-01            3.453897            3.453897                      0.0
# 2004-08-01            3.452074            3.452074                      0.0
# 2004-09-01            3.444803            3.444803                      0.0
#
#             CASUAL_CARPOOL  BART_STRIKE  RIDERS_DIFF  SERVMILES_DIFF
# MONTH
# 2001-01-01               1            0          NaN             NaN
# 2001-02-01               1            0          NaN             NaN
# 2001-03-01               1            0          NaN             NaN
# 2001-04-01               1            0          NaN             NaN
# 2001-05-01               1            0          NaN             NaN
# 2001-06-01               1            0          NaN             NaN
# 2001-07-01               1            0          NaN             NaN
# 2001-08-01               1            0          NaN             NaN
# 2001-09-01               1            0          NaN             NaN
# 2001-10-01               1            0          NaN             NaN
# 2001-11-01               1            0          NaN             NaN
# 2001-12-01               1            0          NaN             NaN
# 2002-01-01               1            0  -20242.9524      -145.07246
# 2002-02-01               1            0  -27136.9474      -145.07246
# 2002-03-01               1            0  -34484.6884      -145.07246
# 2002-04-01               1            0  -21921.4741      -145.07246
# 2002-05-01               1            0  -29379.1818      -145.07246
# 2002-06-01               1            0  -26717.9095      -145.07246
# 2002-07-01               1            0  -23644.9810       192.85081
# 2002-08-01               1            0  -25284.8675       192.85081
# 2002-09-01               1            0  -11681.0921       192.85081
# 2002-10-01               1            0  -11774.8636       192.85081
# 2002-11-01               1            0  -23465.0030       192.85081
# 2002-12-01               1            0   -9768.4064       192.85081
# 2003-01-01               1            0  -12299.9524       192.85081
# 2003-02-01               1            0  -12222.6842       192.85081
# 2003-03-01               1            0   -9507.0476       192.85081
# 2003-04-01               1            0  -18923.8181       192.85081
# 2003-05-01               1            0  -14787.3679       192.85081
# 2003-06-01               1            0  -12419.9000       192.85081
# 2003-07-01               1            0   -2009.1645      1516.74556
# 2003-08-01               1            0    5915.2402      1516.74556
# 2003-09-01               1            0    4042.2024      1516.74556
# 2003-10-01               1            0   11994.4545      1516.74556
# 2003-11-01               1            0   14605.9380      1516.74556
# 2003-12-01               1            0   13848.1579      1516.74556
# 2004-01-01               1            0    8182.5915      1516.74556
# 2004-02-01               1            0    9722.7895      1516.74556
# 2004-03-01               1            0   12184.4514      1516.74556
# 2004-04-01               1            0   17922.4545      1516.74556
# 2004-05-01               1            0   21096.3452      1516.74556
# 2004-06-01               1            0   18482.5455      1516.74556
# 2004-07-01               1            0    9278.4979     -1028.97200
# 2004-08-01               1            0    2336.0325     -1028.97200
# 2004-09-01               1            0    9553.6190     -1028.97200
#
# [45 rows x 24 columns]

# %%
fig = sm.graphics.tsa.plot_acf(bartdf['SERVMILES_DIFF'], lags=176)

# %%
fig = sm.graphics.tsa.plot_acf(bartdf['TOTEMP'], lags=176)

# %%
mod = smf.ols('RIDERS_DIFF ~ SERVMILES_DIFF + CASH_FARE_2010USD_BART + LEISURE_EMP+POP+FUEL_COST_2010USD+TOLL_BB_PK_2010USD+TOLL_BB_CARPOOL_2010USD+TOLL_BB_OP_2010USD+CASUAL_CARPOOL', data=bartdf)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            RIDERS_DIFF   R-squared:                       0.470
# Model:                            OLS   Adj. R-squared:                  0.441
# Method:                 Least Squares   F-statistic:                     16.31
# Date:                Mon, 10 Apr 2017   Prob (F-statistic):           4.08e-17
# Time:                        13:09:31   Log-Likelihood:                -1718.9
# No. Observations:                 156   AIC:                             3456.
# Df Residuals:                     147   BIC:                             3483.
# Df Model:                           8
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                6.896e+05   2.25e+05      3.070      0.003    2.46e+05    1.13e+06
# SERVMILES_DIFF              6.7819      1.585      4.280      0.000       3.650       9.913
# CASH_FARE_2010USD_BART   3.324e+04   1.39e+04      2.396      0.018    5820.829    6.07e+04
# LEISURE_EMP                 0.4461      0.255      1.747      0.083      -0.059       0.951
# POP                        -0.1428      0.030     -4.744      0.000      -0.202      -0.083
# FUEL_COST_2010USD        2.396e+05   7.68e+04      3.117      0.002    8.77e+04    3.91e+05
# TOLL_BB_PK_2010USD      -4.191e+04   1.75e+04     -2.402      0.018   -7.64e+04   -7426.746
# TOLL_BB_CARPOOL_2010USD -1.159e+05   4.67e+04     -2.481      0.014   -2.08e+05   -2.36e+04
# TOLL_BB_OP_2010USD       5.083e+04   2.01e+04      2.532      0.012    1.12e+04    9.05e+04
# CASUAL_CARPOOL          -3.878e+05   1.49e+05     -2.596      0.010   -6.83e+05   -9.26e+04
# ==============================================================================
# Omnibus:                       51.755   Durbin-Watson:                   1.414
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              962.524
# Skew:                          -0.547   Prob(JB):                    9.78e-210
# Kurtosis:                      15.120   Cond. No.                     2.54e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.95e-18. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
sns.jointplot(x="FUEL_PRICE_2010USD", y="FUEL_COST_2010USD", data=bartdf)
